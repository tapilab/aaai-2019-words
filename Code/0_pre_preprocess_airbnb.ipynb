# %% [markdown]
# # Airbnb preprocess
# - 1.Select cities and neighborhoods to explore <br>
# - 2.Get crime rate for neighborhoods from areavibe <br>
# - 3.Generate common words and remove city specific words <br>
#
# - The above preprocess steps are only designed for Airbnb dataset

# %%
import requests, time, operator, re, json, csv, pickle, random
import pandas as pd
import numpy as np
from collections import Counter
from bs4 import BeautifulSoup
import nltk.data
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import KFold

import warnings
warnings.filterwarnings("ignore")
data_path = '/data/2/zwang/2018_S_WordTreatment/V2_airbnb/0_Data/'
list_path = '/data/2/zwang/2017_M_F/airbnb/Data/listing_by_city/'

# %% [markdown]
# <a id='part1'></a>
# ### 1.Select neighborhoods to explore [Home](#home)<br>
# - Define cities to explre<br>
# - Only explore cities that has crime data from FBI<br>
# > Average crime per person<br>
# > http://www.freep.com/story/news/2017/09/25/database-2016-fbi-crime-statistics-u-s-city/701445001/

# %%
city_info = {}
#city_info['city'] = ['state','population','crime','crime_per_1000']

city_info['WDC'] = ['District of Columbia', 681170, 7711, 11]
city_info['SantaCruz'] = ['California', 64969, 521, 8]
city_info['Portland'] = ['Oregon', 642129, 3163, 5]
city_info['Austin'] = ['Texas', 956911, 3903, 4]
city_info['LA'] = ['California', 4007905, 28817, 7]
city_info['Denver'] = ['Colorado', 699259, 4597, 7]
city_info['Boston'] = ['Massachusetts', 673880, 4767, 7]
city_info['NewOrleans'] = ['Louisiana', 397208, 4249, 11]
city_info['Seattle'] = ['Washington', 700313, 4294, 6]
city_info['Oakland'] = ['California', 424998, 6059, 14]
city_info['NY'] = ['New York', 8566917, 49124, 6]
city_info['Nashville'] = ['Tennessee', 668685, 7371, 11]
city_info['Chicago'] = ['Illinois', 2725153, 30126, 11]
city_info['SanDiego'] = ['California', 1413414, 5332, 4]
city_info['Asheville'] = ['North Carolina', 89546, 537, 6]
city_info['SanFrancisco'] = ['California', 871155, 6190, 7]

# %% [markdown]
# - 1.2 Count neighborhoods in each city

# %%
def get_city_hoods(mydata,city_names):
    """
    Iterate over each city's listing file to count neighborhoods of that city.
    city_all_hoods[city] = {hood:n_frequency}
    """
    city_all_hoods = {}
    
    for city in city_names:
        city_pd = pd.read_csv(open(mydata+city+"_listings.csv"))
        dedup_city_pd = city_pd.drop_duplicates('neighborhood_overview',keep='last')
        city_pd_notnull = dedup_city_pd[dedup_city_pd['neighborhood_overview'].notnull()]
        
        hood_ct = Counter(city_pd_notnull[city_pd_notnull['neighbourhood_cleansed'].notnull()].neighbourhood_cleansed)
        city_all_hoods[city] = hood_ct
        
        print("get %d neighborhoods for %s" % (len(hood_ct),city))
        
    return city_all_hoods

# %%
city_all_hoods = get_city_hoods(list_path,list(city_info.keys()))
# Out:
# get 219 neighborhoods for NY
# get 92 neighborhoods for Portland
# get 37 neighborhoods for SanFrancisco
# get 8 neighborhoods for Asheville
# get 5 neighborhoods for SantaCruz
# get 69 neighborhoods for NewOrleans
# get 96 neighborhoods for SanDiego
# get 35 neighborhoods for Nashville
# get 74 neighborhoods for Chicago
# get 74 neighborhoods for Denver
# get 87 neighborhoods for Seattle
# get 39 neighborhoods for WDC
# get 25 neighborhoods for Boston
# get 108 neighborhoods for Oakland
# get 248 neighborhoods for LA
# get 43 neighborhoods for Austin

# %%
city_all_hoods['Boston']
# Out:
# Counter({'Allston': 188,
#          'Back Bay': 209,
#          'Bay Village': 21,
#          'Beacon Hill': 144,
#          'Brighton': 137,
#          'Charlestown': 90,
#          'Chinatown': 20,
#          'Dorchester': 162,
#          'Downtown': 105,
#          'East Boston': 105,
#          'Fenway': 155,
#          'Hyde Park': 22,
#          'Jamaica Plain': 302,
#          'Leather District': 4,
#          'Longwood Medical Area': 12,
#          'Mattapan': 19,
#          'Mission Hill': 59,
#          'North End': 103,
#          'Roslindale': 52,
#          'Roxbury': 114,
#          'South Boston': 132,
#          'South Boston Waterfront': 39,
#          'South End': 226,
#          'West End': 26,
#          'West Roxbury': 28})

# %%
def select_common_hoods(city_all_hoods, threshold):
    """
    Remove uncommon hoods if number of hood_overviews is less than a threshold.
    """
    city_common_hoods = {}
    for city in city_all_hoods:
        city_common_hoods[city] = {}
        cm_hoods = {}
        for hood,ct in city_all_hoods[city].items():
            if(ct >= threshold):
                cm_hoods[hood]=ct
            else:
                print("Drop neighborhood %s in city %s" % (hood,city))
        city_common_hoods[city] = cm_hoods
    return city_common_hoods

city_hoods = select_common_hoods(city_all_hoods, threshold=1)

# %%
n_total = 0
for city in city_hoods:
    n_hood = len(city_hoods[city])
    n_total += n_hood
    print("%d neighborhoods in %s" % (n_hood,city))
print("\n--------------\n%d hoods for %d cities" % (n_total,len(city_hoods)))
# Out:
# 219 neighborhoods in NY
# 92 neighborhoods in Portland
# 37 neighborhoods in SanFrancisco
# 8 neighborhoods in Asheville
# 5 neighborhoods in SantaCruz
# 69 neighborhoods in NewOrleans
# 96 neighborhoods in SanDiego
# 35 neighborhoods in Nashville
# 74 neighborhoods in Chicago
# 74 neighborhoods in Denver
# 87 neighborhoods in Seattle
# 39 neighborhoods in WDC
# 25 neighborhoods in Boston
# 108 neighborhoods in Oakland
# 248 neighborhoods in LA
# 43 neighborhoods in Austin
#
# --------------
# 1259 hoods for 16 cities

# %% [markdown]
# <a id='part2'></a>
# ### 2.Get crime rate for neighborhoods [Home](#home)<br>
# - From areavibes

# %%
def get_state_abbre():
    """ 
    scrape short name for each state, this is used for scraping hood crime rate from areavibes website.
    """
    
    state_abbre = {}
    url = "https://www.50states.com/abbreviations.htm"
    r = requests.get(url)
    if r.ok:
        soup = BeautifulSoup(r.text, 'html.parser')
        for state in soup.find('table', attrs={'class': 'spaced stripedRows'}).text.split('\n'):
            if(state[:-2]):
                state_abbre[state[:-2]] = state[-2:]
    else:
        print("Website not available")
    return state_abbre

state_abbre = get_state_abbre()

# %%
pickle.dump(state_abbre, open(data_path+'state_abbrev.pickle','wb'))

# %%
# map city name to areavibes names
map_city = {}
map_city['SanFrancisco'] = 'San+Francisco'
map_city['NewOrleans'] = 'New+Orleans'
map_city['LA'] = 'Los+Angeles'
map_city['NY'] = 'New+York'
map_city['WDC'] = 'Washington'
map_city['SanDiego'] = 'San+Diego'
map_city['SantaCruz'] = 'Santa+Cruz'

# %%
def scrape_hood_crime(city_hoods,city_info,map_city,state_abbre):
    """
    For every city, iterate over all neighborhoods in that city, to scrape crime rate for that neighborhood.
    """
    crime_info = []
    city_hood_crime = {}
    for city in city_hoods:
        city_hood_crime[city] = {}
        hood_crime = {}
        state = state_abbre[city_info[city][0]]
        if(city in map_city):
            city_name = map_city[city]
        else:
            city_name = city
        
        print('---------------',"crime rate for neighborhoods in", city,state,'---------------')
        
        for hood in city_hoods[city]:
            hoodname = '+'.join(str(hood).split())
            url = "http://www.areavibes.com/%s-%s/%s/crime/" % (city_name.lower(),state.lower(),hoodname.lower())
            r = requests.get(url)
            time.sleep(.5)
            if not r.ok:
                url = 'http://www.areavibes.com/%s-%s/crime/' % (hoodname.lower(), state.lower())
                r = requests.get(url)
                time.sleep(.5)
            
            if r.ok:
                soup = BeautifulSoup(r.text, 'html.parser')
                print('hood: %s' % hood)
                
                try:
                    hood_crime[hood] = 1 / int(soup.find('div', attrs={'class': 'chance-item vc'}).text.split()[-1])
                    crime_info.append({'city':city, 'hood':hood, 'crime':hood_crime[hood]})
                except Exception as e:
                    print('>>>exception parsing crime rate for %s\n%s' % (hood, e))
            else:
                print('>>>failed %s' % hood)
        
        city_hood_crime[city] = hood_crime
        
    pickle.dump(crime_info,open(data_path + 'city_hood_crime.pickle','wb'))
    
    return city_hood_crime

# %%
# This process takes about 20 minutes
city_hood_crime = scrape_hood_crime(city_hoods,city_info,map_city,state_abbre)
# Out:
# --------------- crime rate for neighborhoods in NY NY ---------------
# hood: Cobble Hill
# hood: Queens Village
# hood: West Village
# >>>failed Astoria
# >>>failed Vinegar Hill
# >>>failed Gravesend
# >>>failed Stuyvesant Town
# >>>failed Sunnyside
# >>>failed Morrisania
# >>>failed Long Island City
# hood: Upper West Side
# >>>failed East Morrisania
# >>>failed Arden Heights
# hood: University Heights
# >>>failed Fort Greene
# >>>failed Kingsbridge
# hood: Financial District
# hood: Bensonhurst
# >>>failed Civic Center
# hood: Howland Hook
# hood: New Brighton
# hood: Brownsville
# hood: Borough Park
# >>>failed North Riverdale
# >>>failed Nolita
# hood: Springfield Gardens
# >>>failed Arrochar
# hood: Jackson Heights
# >>>failed Ditmars Steinway
# hood: Little Italy
# hood: Woodrow
# >>>failed Grant City
# >>>failed Richmond Hill
# hood: Jamaica
# >>>failed Bay Terrace
# hood: Laurelton
# >>>failed Stapleton
# >>>failed Prospect Heights
# >>>failed Sheepshead Bay
# >>>failed Unionport
# hood: Riverdale
# >>>failed Pelham Gardens
# hood: Flushing
# hood: SoHo
# >>>failed Throgs Neck
# hood: Hunts Point
# hood: Eastchester
# >>>failed St. Albans
# >>>failed Kips Bay
# >>>failed Hollis Hills
# hood: Canarsie
# >>>failed Edenwald
# >>>failed Brighton Beach
# hood: Parkchester
# >>>failed Midwood
# hood: Flatbush
# >>>exception parsing crime rate for Flatbush
# invalid literal for int() with base 10: 'is'
# >>>failed Theater District
# >>>failed Woodhaven
# >>>failed Bay Terrace, Staten Island
# hood: Port Richmond
# >>>failed West Brighton
# >>>failed Rego Park
# hood: Woodside
# hood: Morris Heights
# >>>failed Rockaway Beach
# >>>failed Jamaica Hills
# hood: Williamsburg
# >>>failed Jamaica Estates
# hood: Midtown
# >>>failed Bayswater
# >>>failed Shore Acres
# >>>failed Briarwood
# >>>failed Elmhurst
# >>>failed Castleton Corners
# >>>failed Bath Beach
# >>>failed St. George
# hood: Bellerose
# hood: Maspeth
# >>>failed Bronxdale
# >>>failed Manhattan Beach
# hood: Forest Hills
# >>>failed Kew Gardens Hills
# hood: Inwood
# hood: South Beach
# hood: East Village
# hood: Mariners Harbor
# hood: Huguenot
# >>>failed Cypress Hills
# >>>failed Navy Yard
# >>>failed Tottenville
# hood: City Island
# >>>failed Downtown Brooklyn
# hood: Todt Hill
# >>>failed East Flatbush
# >>>failed Williamsbridge
# >>>failed Silver Lake
# >>>failed Douglaston
# >>>failed Woodlawn
# hood: Morris Park
# hood: Greenwich Village
# hood: Oakwood
# >>>failed Neponsit
# hood: Park Slope
# >>>failed Emerson Hill
# >>>failed Gowanus
# hood: Prince's Bay
# >>>failed Clason Point
# >>>failed Marble Hill
# hood: Boerum Hill
# >>>failed Flatlands
# >>>failed Windsor Terrace
# hood: Tremont
# hood: Whitestone
# >>>failed Roosevelt Island
# >>>failed Hollis
# >>>failed New Dorp Beach
# hood: Richmondtown
# >>>failed South Ozone Park
# hood: Upper East Side
# hood: Bedford-Stuyvesant
# >>>failed Bergen Beach
# hood: Tribeca
# >>>failed Holliswood
# >>>failed Kew Gardens
# >>>failed East Elmhurst
# >>>failed Grymes Hill
# >>>failed Two Bridges
# hood: Great Kills
# >>>failed Edgemere
# hood: Kensington
# >>>failed Co-op City
# >>>failed Clinton Hill
# hood: Harlem
# >>>failed Ozone Park
# hood: Dyker Heights
# >>>failed Mount Hope
# >>>failed Glen Oaks
# hood: Corona
# >>>failed Tompkinsville
# hood: Country Club
# hood: Bayside
# >>>exception parsing crime rate for Bayside
# invalid literal for int() with base 10: 'is'
# hood: Midland Beach
# >>>failed Port Morris
# hood: Spuyten Duyvil
# hood: Coney Island
# >>>exception parsing crime rate for Coney Island
# invalid literal for int() with base 10: 'is'
# hood: Sunset Park
# >>>failed Sea Gate
# >>>failed Far Rockaway
# hood: Mott Haven
# hood: Carroll Gardens
# >>>failed West Farms
# hood: Bay Ridge
# hood: Chinatown
# hood: Belmont
# >>>failed Randall Manor
# hood: Rosedale
# >>>exception parsing crime rate for Rosedale
# invalid literal for int() with base 10: 'is'
# hood: College Point
# >>>exception parsing crime rate for College Point
# invalid literal for int() with base 10: 'is'
# >>>failed Brooklyn Heights
# hood: Chelsea
# >>>failed Concourse
# >>>failed Greenpoint
# >>>failed Chelsea, Staten Island
# hood: Schuylerville
# >>>failed Arverne
# >>>failed New Springville
# >>>failed Cambria Heights
# hood: Middle Village
# >>>failed South Slope
# >>>failed Dongan Hills
# >>>failed East New York
# >>>failed Fieldston
# >>>failed Fort Hamilton
# >>>failed Mount Eden
# hood: Lower East Side
# >>>failed Allerton
# hood: Howard Beach
# >>>exception parsing crime rate for Howard Beach
# invalid literal for int() with base 10: 'is'
# >>>failed Little Neck
# >>>failed Fresh Meadows
# >>>failed Gerritsen Beach
# hood: Murray Hill
# >>>failed Longwood
# >>>failed Olinville
# hood: Glendale
# hood: Baychester
# >>>failed Columbia St
# >>>failed Prospect-Lefferts Gardens
# >>>failed DUMBO
# >>>failed Hell's Kitchen
# >>>failed Mill Basin
# hood: Norwood
# hood: Gramercy
# >>>failed Battery Park City
# >>>failed Belle Harbor
# >>>failed Pelham Bay
# hood: Ridgewood
# >>>failed Flatiron District
# >>>failed Highbridge
# >>>failed Claremont Village
# >>>failed Graniteville
# >>>failed Concord
# >>>failed Wakefield
# hood: Bushwick
# >>>failed Lighthouse Hill
# >>>failed Eltingville
# hood: Crown Heights
# hood: Rosebank
# >>>failed Concourse Village
# hood: Red Hook
# >>>exception parsing crime rate for Red Hook
# invalid literal for int() with base 10: 'is'
# hood: Fordham
# hood: Morningside Heights
# hood: Soundview
# >>>failed NoHo
# >>>failed Westchester Square
# >>>failed Bull's Head
# hood: Washington Heights
# hood: Clifton
# >>>failed Van Nest
# hood: East Harlem
# >>>failed Melrose
# --------------- crime rate for neighborhoods in Portland OR ---------------
# >>>failed Marshall Park
# hood: Boise
# >>>failed Goose Hollow
# hood: Reed
# >>>failed Sylvan-Highlands
# >>>failed East Columbia
# hood: Bridlemile
# hood: Homestead
# >>>failed Sunnyside
# >>>failed Markham
# hood: Hayhurst
# >>>failed Sellwood-Moreland Improvement League
# >>>failed Powellhurst-Gilbert
# hood: Hillsdale
# >>>failed Laurelhurst
# hood: University Park
# >>>failed Glenfair
# >>>failed Beaumont-Wilshire
# hood: Mill Park
# hood: Lents
# hood: Montavilla
# hood: Centennial
# >>>failed Multnomah
# >>>failed Parkrose Heights
# hood: Buckman
# hood: Forest Park
# hood: Sunderland
# >>>failed Mt. Tabor
# hood: Kerns
# hood: Alameda
# hood: Cully
# hood: Kenton
# hood: Linnton
# hood: King
# hood: Argay
# hood: Wilkes
# >>>failed West Portland Park
# >>>failed Old Town/Chinatown
# >>>failed Sullivan's Gulch
# >>>failed Vernon
# hood: Far Southwest
# >>>failed Sumner
# >>>failed South Portland
# >>>failed Russell
# >>>failed Hayden Island
# hood: Eliot
# hood: Roseway
# >>>failed Grant Park
# >>>failed Hosford-Abernethy
# hood: Concordia
# hood: Southwest Hills
# >>>failed St. Johns
# hood: Overlook
# hood: Arbor Lodge
# >>>failed Portsmouth
# >>>failed Northwest District
# >>>failed Piedmont
# >>>failed Collins View
# hood: Madison South
# >>>failed Ashcreek
# hood: South Tabor
# hood: Woodstock
# >>>failed Hollywood
# >>>failed Arnold Creek
# >>>failed Pearl
# >>>failed South Burlingame
# >>>failed Humboldt
# >>>failed Ardenwald-Johnson Creek
# hood: Parkrose
# >>>failed Brooklyn Action Corps
# hood: Richmond
# hood: Creston-Kenilworth
# >>>failed Portland Downtown
# >>>failed Foster-Powell
# hood: Hazelwood
# hood: Eastmoreland
# >>>failed Maplewood
# >>>failed North Tabor
# hood: Woodlawn
# >>>failed Lloyd District
# hood: Pleasant Valley
# hood: Brentwood-Darlington
# >>>failed Rose City Park
# >>>failed Hillside
# >>>failed Arlington Heights
# >>>failed Northwest Heights
# >>>failed Crestwood
# hood: Irvington
# >>>failed Mt. Scott-Arleta
# hood: Bridgeton
# >>>failed Sabin
# hood: Cathedral Park
# --------------- crime rate for neighborhoods in SanFrancisco CA ---------------
# hood: Russian Hill
# hood: South of Market
# hood: Outer Richmond
# >>>failed Downtown/Civic Center
# hood: Crocker Amazon
# hood: West of Twin Peaks
# hood: Mission
# hood: Visitacion Valley
# >>>failed Haight Ashbury
# hood: Noe Valley
# hood: Seacliff
# >>>failed Golden Gate Park
# hood: Marina
# >>>exception parsing crime rate for Marina
# invalid literal for int() with base 10: 'is'
# hood: Inner Sunset
# hood: Nob Hill
# hood: Inner Richmond
# hood: Parkside
# hood: Twin Peaks
# hood: Lakeshore
# >>>exception parsing crime rate for Lakeshore
# invalid literal for int() with base 10: 'is'
# hood: Ocean View
# hood: Outer Mission
# hood: Bernal Heights
# hood: Financial District
# >>>failed Presidio
# >>>failed Castro/Upper Market
# >>>failed Treasure Island/YBI
# hood: Pacific Heights
# hood: North Beach
# hood: Western Addition
# hood: Glen Park
# hood: Chinatown
# >>>exception parsing crime rate for Chinatown
# invalid literal for int() with base 10: 'is'
# hood: Diamond Heights
# hood: Presidio Heights
# hood: Excelsior
# hood: Potrero Hill
# hood: Outer Sunset
# hood: Bayview
# --------------- crime rate for neighborhoods in Asheville NC ---------------
# >>>failed 28704
# >>>failed 28801
# >>>failed 28803
# >>>failed 28804
# >>>failed 28805
# >>>failed 28806
# >>>failed 28715
# >>>failed 28732
# --------------- crime rate for neighborhoods in SantaCruz CA ---------------
# >>>failed City of Santa Cruz
# >>>failed Unincorporated Areas
# >>>failed City of Watsonville
# >>>failed City of Scotts Valley
# >>>failed City of Capitola
# --------------- crime rate for neighborhoods in NewOrleans LA ---------------
# hood: Lakewood
# hood: Bywater
# hood: Gert Town
# hood: Audubon
# hood: Black Pearl
# hood: Fillmore
# hood: Pontchartrain Park
# >>>failed Marlyville - Fontainbleau
# hood: Garden District
# >>>failed East Carrollton
# >>>failed Hollygrove
# hood: Mid-City
# hood: Navarre
# hood: Dillard
# >>>failed New Aurora - English Turn
# >>>failed Algiers Point
# hood: West End
# hood: Seventh Ward
# hood: Gentilly Woods
# >>>failed Bayou St. John
# hood: Touro
# hood: Central City
# hood: East Riverside
# hood: City Park
# >>>failed U.S. Naval Base
# hood: Lake Catherine
# hood: Milneburg
# >>>failed St. Thomas Dev
# hood: French Quarter
# >>>failed B. W. Cooper
# >>>failed Tall Timbers - Brechtel
# hood: Little Woods
# >>>failed St. Roch
# hood: Lakeview
# hood: West Riverside
# >>>failed St. Claude
# hood: Iberville
# >>>exception parsing crime rate for Iberville
# invalid literal for int() with base 10: 'is'
# hood: Read Blvd East
# hood: Old Aurora
# >>>failed St.  Anthony
# >>>failed Florida Area
# hood: Central Business District
# >>>failed Lake Terrace & Oaks
# hood: Leonidas
# >>>failed Tulane - Gravier
# >>>failed Treme - Lafitte
# hood: Broadmoor
# hood: Plum Orchard
# hood: Lower Garden District
# hood: Irish Channel
# >>>failed Lakeshore - Lake Vista
# >>>failed St. Bernard Area
# hood: Gentilly Terrace
# >>>failed Desire Area
# hood: Whitney
# hood: Pines Village
# hood: Milan
# hood: Freret
# hood: Read Blvd West
# hood: Uptown
# >>>failed Village De Lest
# hood: West Lake Forest
# >>>failed Lower Ninth Ward
# hood: Marigny
# hood: Holy Cross
# hood: Fairgrounds
# hood: Dixon
# hood: Mcdonogh
# hood: Behrman
# --------------- crime rate for neighborhoods in SanDiego CA ---------------
# >>>failed East Lake
# hood: Paradise Hills
# hood: West University Heights
# >>>failed Yosemite Dr
# hood: El Cerritos
# hood: Talmadge
# hood: Cortez Hill
# hood: Del Mar Heights
# hood: Gateway
# hood: City Heights East
# >>>failed Eastlake Woods
# hood: La Jolla Village
# hood: Old Town
# hood: Kensington
# hood: Ocean Beach
# hood: Palm City
# hood: Jomacha-Lomita
# hood: Midtown District
# hood: Columbia
# hood: Linda Vista
# hood: San Carlos
# hood: Rancho Bernadino
# hood: North Clairemont
# hood: Grant Hill
# hood: Rancho Penasquitos
# hood: Little Italy
# hood: Carmel Valley
# hood: College Area
# hood: Scripps Ranch
# hood: Mira Mesa
# hood: Kearny Mesa
# hood: Valencia Park
# hood: Bay Terrace
# hood: Mission Bay
# hood: Oak Park
# hood: Grantville
# hood: Roseville
# >>>failed Rancho Del Rey
# >>>failed Otay Ranch
# >>>failed Southwest
# hood: Chollas View
# >>>failed Eastlake Trails
# hood: Egger Highlands
# hood: South Park
# >>>exception parsing crime rate for South Park
# invalid literal for int() with base 10: 'is'
# hood: City Heights West
# >>>failed Eastlake Vistas
# hood: Normal Heights
# hood: Mission Valley
# >>>exception parsing crime rate for Mission Valley
# invalid literal for int() with base 10: 'is'
# hood: University City
# hood: Allied Gardens
# hood: Webster
# >>>exception parsing crime rate for Webster
# invalid literal for int() with base 10: 'is'
# hood: Marina
# >>>failed Lynwood Hills
# hood: Del Cerro
# hood: Loma Portal
# hood: Gaslamp Quarter
# hood: Serra Mesa
# hood: Darnall
# hood: Nestor
# >>>failed Rolling Hills Ranch
# hood: Sabre Springs
# hood: Midtown
# >>>exception parsing crime rate for Midtown
# invalid literal for int() with base 10: 'is'
# hood: Park West
# hood: Encanto
# hood: Mountain View
# hood: Bird Land
# hood: San Ysidro
# hood: Alta Vista
# hood: Rolando
# hood: Horton Plaza
# hood: Bay Park
# hood: East Village
# hood: North City
# >>>failed Paseo Ranchoero
# >>>failed Sunbow
# hood: North Hills
# >>>exception parsing crime rate for North Hills
# invalid literal for int() with base 10: 'is'
# hood: Core
# hood: Balboa Park
# hood: Bay Ho
# hood: Sky Line
# hood: Moreno Mission
# hood: Tierrasanta
# hood: Clairemont Mesa
# hood: Mount Hope
# hood: Lake Murray
# hood: Sorrento Valley
# hood: Torrey Pines
# >>>failed Northwest
# hood: La Jolla
# hood: Southcrest
# hood: Wooded Area
# hood: Pacific Beach
# >>>failed Estlake Greens
# hood: Memorial
# hood: Bario Logan
# hood: Carmel Mountain
# --------------- crime rate for neighborhoods in Nashville TN ---------------
# >>>failed District 3
# >>>failed District 6
# >>>failed District 26
# >>>failed District 20
# >>>failed District 13
# >>>failed District 34
# >>>failed District 15
# >>>failed District 1
# >>>failed District 21
# >>>failed District 5
# >>>failed District 25
# >>>failed District 12
# >>>failed District 29
# >>>failed District 17
# >>>failed District 31
# >>>failed District 9
# >>>failed District 10
# >>>failed District 7
# >>>failed District 19
# >>>failed District 22
# >>>failed District 8
# >>>failed District 16
# >>>failed District 18
# >>>failed District 11
# >>>failed District 27
# >>>failed District 4
# >>>failed District 30
# >>>failed District 2
# >>>failed District 35
# >>>failed District 24
# >>>failed District 14
# >>>failed District 28
# >>>failed District 33
# >>>failed District 23
# >>>failed District 32
# --------------- crime rate for neighborhoods in Chicago IL ---------------
# hood: Mckinley Park
# hood: Chicago Lawn
# hood: Edison Park
# hood: Dunning
# hood: Avondale
# hood: South Shore
# hood: Norwood Park
# hood: Forest Glen
# hood: Loop
# hood: Rogers Park
# hood: Armour Square
# hood: Morgan Park
# hood: Mount Greenwood
# hood: Grand Boulevard
# hood: Lower West Side
# hood: Washington Park
# hood: West Ridge
# hood: Ashburn
# hood: North Center
# hood: West Elsdon
# hood: East Garfield Park
# hood: Hermosa
# hood: Oakland
# hood: Clearing
# hood: Near South Side
# hood: West Lawn
# hood: Burnside
# hood: Pullman
# hood: Douglas
# hood: Humboldt Park
# hood: Chatham
# hood: West Town
# hood: Fuller Park
# hood: Lincoln Square
# hood: Austin
# hood: West Englewood
# hood: South Deering
# hood: South Chicago
# hood: West Garfield Park
# hood: Belmont Cragin
# hood: Lake View
# hood: Edgewater
# hood: Near West Side
# hood: North Park
# hood: Beverly
# hood: Albany Park
# hood: Logan Square
# >>>failed Ohare
# hood: Woodlawn
# hood: Bridgeport
# hood: Roseland
# hood: Brighton Park
# hood: South Lawndale
# hood: Irving Park
# hood: Near North Side
# hood: Archer Heights
# hood: New City
# hood: Kenwood
# >>>failed Greater Grand Crossing
# >>>failed Portage Park
# hood: Montclare
# hood: Calumet Heights
# hood: Auburn Gresham
# hood: Hegewisch
# hood: Jefferson Park
# hood: Washington Heights
# hood: Lincoln Park
# hood: Garfield Ridge
# hood: West Pullman
# hood: Hyde Park
# hood: North Lawndale
# hood: Uptown
# hood: Gage Park
# hood: Englewood
# --------------- crime rate for neighborhoods in Denver CO ---------------
# hood: Five Points
# >>>failed Whittier
# >>>failed North Capitol Hill
# >>>failed CBD
# >>>failed Sloan Lake
# >>>failed Marston
# >>>failed Hilltop
# >>>failed Wellshire
# >>>failed Goldsmith
# >>>failed Sunnyside
# hood: Cherry Creek
# >>>failed Berkeley
# >>>failed Barnum West
# >>>failed Hampden South
# hood: Washington Park
# >>>failed Indian Creek
# >>>failed North Park Hill
# >>>failed City Park West
# >>>failed Washington Virginia Vale
# >>>failed DIA
# >>>failed Hampden
# >>>failed Congress Park
# hood: Highland
# >>>failed Civic Center
# >>>failed Westwood
# >>>failed University Park
# >>>failed Northeast Park Hill
# >>>failed Country Club
# >>>failed Harvey Park South
# >>>failed Globeville
# >>>failed West Highland
# >>>failed University Hills
# >>>failed Fort Logan
# >>>failed Washington Park West
# >>>failed Platt Park
# >>>failed Speer
# >>>failed Montclair
# >>>failed Southmoor Park
# hood: Lincoln Park
# hood: Auraria
# >>>failed Union Station
# >>>failed Harvey Park
# >>>failed Barnum
# >>>failed Hale
# >>>failed Belcaro
# hood: City Park
# hood: Capitol Hill
# >>>failed Villa Park
# >>>failed Cory - Merrill
# >>>failed Rosedale
# hood: Stapleton
# >>>failed East Colfax
# >>>failed Cheesman Park
# >>>failed Lowry Field
# >>>failed Athmar Park
# >>>failed Overland
# >>>failed Clayton
# >>>failed Skyland
# hood: University
# >>>failed Virginia Village
# >>>failed Ruby Hill
# >>>failed Chaffee Park
# >>>failed Mar Lee
# >>>failed South Park Hill
# hood: Jefferson Park
# >>>failed Bear Valley
# hood: Windsor
# hood: Baker
# >>>failed Regis
# >>>failed Gateway - Green Valley Ranch
# >>>failed Cole
# >>>failed College View - South Platte
# >>>failed Valverde
# >>>failed West Colfax
# --------------- crime rate for neighborhoods in Seattle WA ---------------
# hood: Alki
# hood: South Lake Union
# >>>failed Broadway
# >>>failed West Woodland
# hood: Bryant
# hood: Arbor Heights
# hood: Green Lake
# >>>failed Fairmount Park
# hood: Victory Heights
# hood: Whittier Heights
# hood: Laurelhurst
# hood: Roxhill
# >>>failed Dunlap
# hood: Ravenna
# hood: Maple Leaf
# hood: Pinehurst
# >>>exception parsing crime rate for Pinehurst
# invalid literal for int() with base 10: 'is'
# hood: Brighton
# hood: View Ridge
# >>>failed Central Business District
# hood: North College Park
# hood: Loyal Heights
# hood: Leschi
# >>>failed Adams
# hood: Riverview
# hood: Bitter Lake
# hood: Portage Bay
# hood: Olympic Hills
# >>>failed Mid-Beacon Hill
# hood: South Park
# >>>failed Southeast Magnolia
# hood: Rainier Beach
# >>>failed North Beach/Blue Ridge
# hood: Wallingford
# hood: Georgetown
# hood: Eastlake
# >>>failed Seaview
# >>>failed East Queen Anne
# hood: Broadview
# hood: Cedar Park
# hood: Columbia City
# hood: Mount Baker
# >>>exception parsing crime rate for Mount Baker
# invalid literal for int() with base 10: 'is'
# hood: Fremont
# >>>failed Yesler Terrace
# >>>failed North Admiral
# hood: Interbay
# hood: University District
# hood: Greenwood
# >>>failed Mann
# hood: International District
# >>>failed North Queen Anne
# >>>failed Pike-Market
# hood: Crown Hill
# hood: First Hill
# hood: Industrial District
# hood: Lower Queen Anne
# hood: Wedgwood
# hood: Roosevelt
# >>>exception parsing crime rate for Roosevelt
# invalid literal for int() with base 10: 'is'
# hood: Atlantic
# >>>failed North Beacon Hill
# hood: Highland Park
# hood: South Delridge
# hood: Belltown
# >>>failed Harrison/Denny-Blaine
# hood: Haller Lake
# >>>failed West Queen Anne
# hood: Matthews Beach
# hood: Fauntleroy
# hood: Sunset Hill
# hood: Montlake
# >>>failed Minor
# >>>failed Holly Park
# >>>failed Genesee
# hood: Westlake
# >>>failed South Beacon Hill
# >>>failed Stevens
# hood: Madison Park
# >>>failed Lawton Park
# hood: Windermere
# >>>failed Gatewood
# hood: Meadowbrook
# hood: Seward Park
# hood: North Delridge
# >>>failed Briarcliff
# hood: Phinney Ridge
# hood: High Point
# hood: Madrona
# hood: Pioneer Square
# --------------- crime rate for neighborhoods in WDC DC ---------------
# >>>failed Columbia Heights, Mt. Pleasant, Pleasant Plains, Park View
# >>>failed Brightwood Park, Crestwood, Petworth
# >>>failed Eastland Gardens, Kenilworth
# >>>failed Congress Heights, Bellevue, Washington Highlands
# >>>failed Ivy City, Arboretum, Trinidad, Carver Langston
# >>>failed Woodland/Fort Stanton, Garfield Heights, Knox Hill
# >>>failed Friendship Heights, American University Park, Tenleytown
# >>>failed Cleveland Park, Woodley Park, Massachusetts Avenue Heights, Woodland-Normanstone Terrace
# >>>failed Georgetown, Burleith/Hillandale
# >>>failed Lamont Riggs, Queens Chapel, Fort Totten, Pleasant Hill
# >>>failed Near Southeast, Navy Yard
# >>>failed Mayfair, Hillbrook, Mahaning Heights
# >>>failed Brookland, Brentwood, Langdon
# >>>failed Downtown, Chinatown, Penn Quarters, Mount Vernon Square, North Capitol Street
# >>>failed Capitol View, Marshall Heights, Benning Heights
# >>>failed North Michigan Park, Michigan Park, University Heights
# >>>failed Deanwood, Burrville, Grant Park, Lincoln Heights, Fairmont Heights
# >>>failed Union Station, Stanton Park, Kingman Park
# >>>failed Kalorama Heights, Adams Morgan, Lanier Heights
# >>>failed Twining, Fairlawn, Randle Highlands, Penn Branch, Fort Davis Park, Fort Dupont
# >>>failed Douglas, Shipley Terrace
# >>>failed Howard University, Le Droit Park, Cardozo/Shaw
# >>>failed Colonial Village, Shepherd Park, North Portal Estates
# >>>failed Dupont Circle, Connecticut Avenue/K Street
# >>>failed Fairfax Village, Naylor Gardens, Hillcrest, Summit Park
# >>>failed Edgewood, Bloomingdale, Truxton Circle, Eckington
# >>>failed River Terrace, Benning, Greenway, Dupont Park
# >>>failed Capitol Hill, Lincoln Park
# >>>failed Spring Valley, Palisades, Wesley Heights, Foxhall Crescent, Foxhall Village, Georgetown Reservoir
# >>>failed Woodridge, Fort Lincoln, Gateway
# >>>failed Southwest Employment Area, Southwest/Waterfront, Fort McNair, Buzzard Point
# >>>failed West End, Foggy Bottom, GWU
# >>>failed North Cleveland Park, Forest Hills, Van Ness
# >>>failed Cathedral Heights, McLean Gardens, Glover Park
# >>>failed Hawthorne, Barnaby Woods, Chevy Chase
# >>>failed Historic Anacostia
# >>>failed Sheridan, Barry Farm, Buena Vista
# >>>failed Shaw, Logan Circle
# >>>failed Takoma, Brightwood, Manor Park
# --------------- crime rate for neighborhoods in Boston MA ---------------
# hood: East Boston
# >>>failed Back Bay
# >>>failed Chinatown
# hood: Charlestown
# hood: Roslindale
# >>>failed West End
# >>>failed Mission Hill
# hood: West Roxbury
# >>>failed Leather District
# >>>failed Dorchester
# >>>failed Downtown
# hood: Hyde Park
# >>>failed Bay Village
# hood: South Boston
# >>>failed Beacon Hill
# hood: Mattapan
# >>>failed Brighton
# hood: Jamaica Plain
# >>>failed Longwood Medical Area
# >>>failed Allston
# >>>failed North End
# hood: Roxbury
# >>>failed South Boston Waterfront
# hood: South End
# >>>failed Fenway
# --------------- crime rate for neighborhoods in Oakland CA ---------------
# hood: Lincoln Highlands
# hood: Clinton
# hood: Webster
# hood: Leona Heights
# hood: Upper Rockridge
# hood: Frick
# hood: Trestle Glen
# hood: Lynn-Highland Park
# hood: Dimond
# hood: Glenview
# hood: Hoover-Foster
# hood: Allendale
# hood: Jefferson
# hood: Oak Tree
# hood: Redwood Heights
# hood: Civic Center
# hood: Fairview Park
# hood: Lake Merritt
# hood: Bella Vista
# hood: Sequoyah
# hood: Rancho San Antonio
# hood: Hawthorne
# hood: Forestland
# hood: McClymonds
# hood: Laurel
# hood: Acorn-Acorn Industrial
# hood: Montclair
# hood: Lakeshore
# hood: Upper Laurel
# hood: Prescott
# hood: Woodland
# hood: Woodminster
# hood: Melrose
# hood: Durant Manor
# hood: Cleveland Heights
# hood: Joaquin Miller Park
# hood: Golf Links
# hood: Peralta-Hacienda
# hood: Millsmont
# hood: Tuxedo
# hood: Bancroft Business-Havenscourt
# hood: Santa Fe
# hood: Maxwell Park
# hood: Lakewide
# hood: Oakland Ave-Harrison St
# hood: Panoramic Hill
# hood: School
# hood: Northgate
# >>>exception parsing crime rate for Northgate
# invalid literal for int() with base 10: 'is'
# hood: Mills College
# >>>exception parsing crime rate for Mills College
# invalid literal for int() with base 10: 'is'
# hood: Eastmont
# hood: Produce And Waterfront
# hood: Hiller Highlands
# hood: Gaskill
# hood: Piedmont Avenue
# hood: Clawson
# hood: Shafter
# hood: Oak Center
# hood: Ivy Hill
# hood: South Prescott
# hood: Chabot Park
# hood: Claremont
# hood: Sausal Creek
# hood: Waverly
# hood: Fremont
# hood: Grand Lake
# hood: Patten
# hood: Piedmont
# hood: Ralph Bunche
# hood: Shepherd Canyon
# hood: Skyline-Hillcrest Estates
# hood: Merritt
# hood: Pill Hill
# hood: Highland
# hood: Merriwood
# hood: San Pablo Gateway
# hood: Sheffield Village
# hood: Toler Heights
# hood: Crestmont
# hood: Paradise Park
# hood: Fairfax
# hood: Temescal
# hood: Eastmont Hills
# hood: Upper Dimond
# hood: Bushrod
# hood: Coliseum
# hood: Bartlett
# hood: South Kennedy Tract
# hood: Adams Point
# hood: Chinatown
# >>>exception parsing crime rate for Chinatown
# invalid literal for int() with base 10: 'is'
# hood: Reservoir Hill-Meadow Brook
# hood: Longfellow
# hood: Peralta-Laney
# hood: Downtown
# >>>exception parsing crime rate for Downtown
# invalid literal for int() with base 10: 'is'
# hood: Sobrante Park
# hood: Crocker Highland
# hood: Caballo Hills
# hood: Mosswood
# hood: Oakmore
# hood: Mountain View Cemetery
# hood: Golden Gate
# hood: Upper Peralta Creek-Bartlett
# hood: Glen Highlands
# hood: Harrington
# hood: East Peralta
# hood: Old City-Produce And Waterfront
# hood: Rockridge
# hood: Highland Terrace
# hood: Piedmont Pines
# --------------- crime rate for neighborhoods in LA CA ---------------
# hood: Glassell Park
# hood: Calabasas
# hood: Echo Park
# hood: Valinda
# hood: Harbor Gateway
# >>>failed Sepulveda Basin
# >>>failed Carthay
# hood: Glendora
# hood: Brentwood
# hood: Winnetka
# hood: Van Nuys
# hood: Temple City
# hood: West Hills
# hood: Downtown
# >>>exception parsing crime rate for Downtown
# invalid literal for int() with base 10: 'is'
# hood: Pico Rivera
# >>>failed Florence
# >>>failed Beverly Crest
# >>>failed Unincorporated Santa Susana Mountains
# hood: Watts
# hood: North El Monte
# >>>failed Hancock Park
# hood: Charter Oak
# hood: Artesia
# hood: Marina del Rey
# hood: Hawthorne
# hood: Downey
# hood: Boyle Heights
# hood: Inglewood
# >>>failed Central-Alameda
# hood: Arleta
# hood: Hacienda Heights
# >>>failed Cheviot Hills
# >>>failed Mid-City
# hood: South El Monte
# hood: Westmont
# hood: Venice
# hood: Citrus
# >>>failed Florence-Firestone
# hood: West Los Angeles
# >>>failed Tujunga Canyons
# >>>failed Koreatown
# hood: Lawndale
# hood: Diamond Bar
# >>>failed Elysian Park
# hood: Hollywood Hills
# hood: Granada Hills
# >>>failed Green Meadows
# hood: Highland Park
# hood: Palms
# hood: North Hollywood
# hood: Montebello
# hood: Palos Verdes Estates
# hood: El Sereno
# hood: Santa Clarita
# hood: Rancho Palos Verdes
# hood: Walnut
# >>>failed Broadway-Manchester
# >>>failed Unincorporated Santa Monica Mountains
# hood: East San Gabriel
# hood: Cypress Park
# hood: Burbank
# hood: La Puente
# hood: Industry
# hood: Century City
# >>>failed Elysian Valley
# hood: Claremont
# hood: Lincoln Heights
# hood: Sun Valley
# hood: Panorama City
# >>>failed Harvard Park
# hood: Hawaiian Gardens
# hood: Huntington Park
# >>>failed Rancho Park
# >>>failed Leimert Park
# hood: Altadena
# hood: Monterey Park
# >>>failed Vermont Square
# >>>failed Rancho Dominguez
# >>>failed Historic South-Central
# hood: East Los Angeles
# hood: Manhattan Beach
# hood: Azusa
# hood: Eagle Rock
# hood: La Crescenta-Montrose
# hood: Pacoima
# hood: Green Valley
# >>>exception parsing crime rate for Green Valley
# invalid literal for int() with base 10: 'is'
# >>>failed Athens
# hood: Studio City
# hood: Tarzana
# hood: Playa Vista
# hood: Atwater Village
# hood: Norwalk
# hood: Rosemead
# hood: Malibu
# hood: North Hills
# >>>failed Lake View Terrace
# hood: West Puente Valley
# hood: Silver Lake
# hood: Encino
# >>>failed Baldwin Hills/Crenshaw
# >>>failed Porter Ranch
# hood: Northridge
# hood: Canoga Park
# hood: El Monte
# hood: Long Beach
# hood: Baldwin Park
# hood: Pacific Palisades
# >>>failed Arlington Heights
# >>>failed Beverly Grove
# hood: Pasadena
# hood: La Verne
# >>>failed North Whittier
# hood: West Hollywood
# >>>failed Mid-Wilshire
# hood: Alhambra
# hood: South Whittier
# hood: Agoura Hills
# hood: Bellflower
# hood: Sunland
# hood: Cerritos
# hood: Whittier
# hood: Alondra Park
# hood: Avocado Heights
# hood: Glendale
# hood: Acton
# hood: Monrovia
# hood: Del Aire
# >>>failed Playa del Rey
# hood: Hermosa Beach
# >>>failed Vermont-Slauson
# hood: Palmdale
# >>>failed Larchmont
# hood: Gardena
# >>>failed Vermont Vista
# >>>failed Veterans Administration
# >>>failed East La Mirada
# hood: Pomona
# hood: San Pasqual
# >>>failed Lopez/Kagel Canyons
# hood: La Habra Heights
# hood: Westwood
# >>>failed University Park
# hood: Rolling Hills
# >>>exception parsing crime rate for Rolling Hills
# division by zero
# >>>failed East Hollywood
# >>>failed Unincorporated Catalina Island
# hood: Signal Hill
# hood: Lomita
# hood: Agua Dulce
# hood: Westlake
# >>>failed Southeast Antelope Valley
# >>>failed Valley Glen
# hood: Irwindale
# hood: Bradbury
# >>>exception parsing crime rate for Bradbury
# division by zero
# hood: San Pedro
# >>>failed Windsor Square
# hood: Santa Fe Springs
# hood: Woodland Hills
# hood: La Mirada
# hood: View Park-Windsor Hills
# hood: Chinatown
# hood: Mission Hills
# >>>exception parsing crime rate for Mission Hills
# invalid literal for int() with base 10: 'is'
# hood: Willowbrook
# hood: Jefferson Park
# hood: Sierra Madre
# hood: Carson
# >>>failed Harvard Heights
# hood: Lakewood
# hood: South Park
# hood: Mayflower Village
# hood: Pico-Robertson
# hood: Mount Washington
# >>>failed Bel-Air
# hood: Stevenson Ranch
# hood: Compton
# >>>failed Lake Balboa
# >>>failed Castaic Canyons
# hood: Topanga
# >>>failed Adams-Normandie
# hood: Fairfax
# hood: West Adams
# hood: South Pasadena
# >>>failed Exposition Park
# hood: Hasley Canyon
# hood: Culver City
# >>>failed Chesterfield Square
# >>>failed Beverlywood
# hood: Hyde Park
# hood: Duarte
# hood: Del Rey
# hood: Ramona
# hood: El Segundo
# hood: South San Gabriel
# hood: Shadow Hills
# hood: Redondo Beach
# hood: Ladera Heights
# hood: Bell
# hood: Castaic
# hood: Rolling Hills Estates
# hood: Chatsworth
# hood: Avalon
# hood: Beverly Hills
# hood: Sawtelle
# hood: Lynwood
# hood: Vincent
# hood: West Covina
# hood: Santa Monica
# hood: Westchester
# hood: Harbor City
# hood: South Gate
# >>>failed Northwest Palmdale
# >>>failed Ridge Route
# hood: Valley Village
# hood: Torrance
# hood: Westlake Village
# >>>failed East Compton
# hood: East Pasadena
# hood: Rowland Heights
# hood: Covina
# hood: Los Feliz
# hood: Lake Hughes
# hood: Reseda
# >>>failed Griffith Park
# >>>failed Angeles Crest
# hood: Montecito Heights
# hood: Tujunga
# >>>failed Vermont Knolls
# hood: West Carson
# >>>failed Manchester Square
# >>>failed Gramercy Park
# >>>failed Universal City
# hood: Lancaster
# hood: San Gabriel
# hood: Wilmington
# >>>exception parsing crime rate for Wilmington
# invalid literal for int() with base 10: 'is'
# hood: Paramount
# hood: San Fernando
# hood: Val Verde
# hood: Mar Vista
# >>>failed Sherman Oaks
# hood: San Marino
# >>>failed Pico-Union
# hood: Arcadia
# hood: La Cañada Flintridge
# hood: Sylmar
# hood: Hollywood
# hood: Toluca Lake
# hood: San Dimas
# >>>failed Hollywood Hills West
# >>>failed Northwest Antelope Valley
# --------------- crime rate for neighborhoods in Austin TX ---------------
# >>>failed 78721
# >>>failed 78722
# >>>failed 78723
# >>>failed 78724
# >>>failed 78725
# >>>failed 78726
# >>>failed 78727
# >>>failed 78728
# >>>failed 78729
# >>>failed 78730
# >>>failed 78731
# >>>failed 78732
# >>>failed 78733
# >>>failed 78734
# >>>failed 78735
# >>>failed 78736
# >>>failed 78737
# >>>failed 78738
# >>>failed 78739
# >>>failed 78741
# >>>failed 78742
# >>>failed 78744
# >>>failed 78745
# >>>failed 78746
# >>>failed 78747
# >>>failed 78748
# >>>failed 78749
# >>>failed 78750
# >>>failed 78751
# >>>failed 78752
# >>>failed 78753
# >>>failed 78754
# >>>failed 78756
# >>>failed 78757
# >>>failed 78758
# >>>failed 78759
# >>>failed 78701
# >>>failed 78702
# >>>failed 78703
# >>>failed 78704
# >>>failed 78705
# >>>failed 78717
# >>>failed 78719

# %%
n_total_hoodcrime = 0
for city in city_hood_crime:
    n_hoodcrime = len(city_hood_crime[city])
    n_total_hoodcrime += n_hoodcrime
    print("Crime rate for %d / %d neighborhoods in %s" % (n_hoodcrime,len(city_hoods[city]),city))

print("\n-------------------------------------------\nGet crime rate for %d out of %d neighborhoods." % (n_total_hoodcrime,n_total))
# Out:
# Crime rate for 84 / 219 neighborhoods in NY
# Crime rate for 43 / 92 neighborhoods in Portland
# Crime rate for 0 / 8 neighborhoods in Asheville
# Crime rate for 28 / 37 neighborhoods in SanFrancisco
# Crime rate for 71 / 74 neighborhoods in Chicago
# Crime rate for 104 / 108 neighborhoods in Oakland
# Crime rate for 77 / 96 neighborhoods in SanDiego
# Crime rate for 0 / 35 neighborhoods in Nashville
# Crime rate for 0 / 5 neighborhoods in SantaCruz
# Crime rate for 13 / 74 neighborhoods in Denver
# Crime rate for 57 / 87 neighborhoods in Seattle
# Crime rate for 0 / 39 neighborhoods in WDC
# Crime rate for 10 / 25 neighborhoods in Boston
# Crime rate for 46 / 69 neighborhoods in NewOrleans
# Crime rate for 177 / 248 neighborhoods in LA
# Crime rate for 0 / 43 neighborhoods in Austin
#
# -------------------------------------------
# Get crime rate for 710 out of 1259 neighborhoods.

# %% [markdown]
# - for hood that has crime info, pickle information ['city','city_crime','hood','hood_crime','overview']

# %%
def store_crimehood_overview(mypath,info_file,city_hood_crime):
    """
    Pickle information into a file, a list of dictionaries.
    ['city','city_crime','hood','hood_crime','hood_overview']
    """
    list_of_infos = []
    
    for city in city_hood_crime:
        print("\n",city)
        city_pd = pd.read_csv(open(mypath+city+"_listings.csv"))
        dedup_city_pd = city_pd.drop_duplicates('neighborhood_overview',keep='last')
        city_pd_notnull = dedup_city_pd[dedup_city_pd['neighborhood_overview'].notnull()]
        
        for hood in city_hood_crime[city]:
            list_of_hoodviews = city_pd_notnull[city_pd_notnull['neighbourhood_cleansed'] == hood].neighborhood_overview.values.tolist()
            for view in list_of_hoodviews:
                view_info = {}
                view_info['city'] = city
                view_info['city_crime'] = city_info[city][-1]/1000
                view_info['hood'] = hood
                view_info['hood_crime'] = city_hood_crime[city][hood]
                view_info['hood_overviews'] = view
                list_of_infos.append(view_info)
            print("%s\t%d" % (hood,len(list_of_hoodviews)))
        
    pickle.dump(list_of_infos,open(info_file,'wb'))
    return

# %%
store_crimehood_overview(list_path,data_path+'city_hood_byview.pickle',city_hood_crime)
# Out:
#  NY
# Cobble Hill	150
# Sunset Park	398
# Boerum Hill	283
# Upper East Side	2517
# Bedford-Stuyvesant	3675
# West Village	1237
# Tribeca	232
# Middle Village	34
# Lower East Side	1463
# Canarsie	92
# Woodside	149
# Belmont	10
# Morris Heights	18
# Midtown	1419
# Kensington	188
# Norwood	41
# University Heights	9
# Williamsburg	5032
# New Brighton	21
# Harlem	3492
# City Island	16
# Dyker Heights	37
# Chelsea	1655
# Financial District	684
# Crown Heights	1858
# Bensonhurst	67
# Bellerose	13
# Maspeth	71
# Corona	62
# Rosebank	2
# Forest Hills	147
# Brownsville	51
# Borough Park	98
# South Beach	5
# Gramercy	473
# East Village	3033
# Springfield Gardens	30
# Spuyten Duyvil	27
# Jackson Heights	242
# Huguenot	2
# Little Italy	143
# Hunts Point	1
# Baychester	4
# Country Club	2
# Mott Haven	51
# Woodrow	1
# Carroll Gardens	309
# Bay Ridge	159
# Chinatown	549
# Mariners Harbor	11
# Midland Beach	15
# Jamaica	115
# Laurelton	9
# Great Kills	5
# Upper West Side	2684
# Morris Park	6
# Greenwich Village	590
# Oakwood	4
# Howland Hook	2
# Park Slope	685
# Riverdale	27
# Richmondtown	4
# Glendale	29
# Flushing	282
# Fordham	31
# Murray Hill	372
# SoHo	608
# Ridgewood	434
# Port Richmond	8
# Eastchester	18
# Schuylerville	3
# Prince's Bay	1
# Morningside Heights	469
# Inwood	381
# Clifton	15
# Tremont	10
# Bushwick	2652
# Whitestone	4
# East Harlem	1591
# Todt Hill	4
# Soundview	4
# Parkchester	44
# Queens Village	48
# Washington Heights	1217
#
#  Portland
# Woodstock	56
# Madison South	28
# Buckman	189
# Southwest Hills	46
# Sunderland	3
# Lents	11
# Woodlawn	114
# Kerns	95
# Overlook	133
# Alameda	35
# Arbor Lodge	62
# Bridlemile	9
# Boise	123
# Eastmoreland	22
# Hazelwood	21
# Cully	67
# Richmond	295
# Pleasant Valley	10
# Linnton	3
# Hayhurst	22
# King	182
# Argay	7
# South Tabor	88
# Wilkes	5
# Creston-Kenilworth	68
# Hillsdale	47
# Eliot	68
# Concordia	237
# Cathedral Park	32
# Bridgeton	6
# University Park	23
# Brentwood-Darlington	24
# Far Southwest	4
# Homestead	21
# Mill Park	2
# Forest Park	16
# Reed	26
# Parkrose	12
# Kenton	94
# Montavilla	102
# Centennial	11
# Irvington	115
# Roseway	54
#
#  Asheville
#
#  SanFrancisco
# Russian Hill	243
# South of Market	684
# Outer Richmond	222
# Crocker Amazon	39
# West of Twin Peaks	157
# Mission	1173
# Visitacion Valley	51
# Noe Valley	416
# Seacliff	18
# Glen Park	94
# Inner Sunset	191
# Nob Hill	332
# Inner Richmond	310
# Parkside	139
# Ocean View	121
# Bernal Heights	549
# Outer Mission	193
# Financial District	101
# Diamond Heights	29
# Twin Peaks	115
# Potrero Hill	331
# Pacific Heights	246
# North Beach	178
# Western Addition	928
# Presidio Heights	48
# Excelsior	161
# Outer Sunset	287
# Bayview	159
#
#  Chicago
# Mckinley Park	9
# Chicago Lawn	2
# Edison Park	3
# Dunning	9
# Avondale	162
# South Shore	27
# Norwood Park	17
# Woodlawn	35
# Loop	191
# Rogers Park	143
# Armour Square	32
# Morgan Park	8
# Mount Greenwood	1
# Grand Boulevard	60
# Lower West Side	204
# Washington Park	7
# West Ridge	56
# Ashburn	2
# North Center	131
# West Elsdon	5
# East Garfield Park	39
# Hermosa	13
# Brighton Park	2
# Clearing	1
# Near South Side	53
# West Lawn	4
# Burnside	1
# Pullman	6
# Douglas	42
# Humboldt Park	57
# Chatham	4
# West Town	848
# Fuller Park	3
# Lincoln Square	129
# Austin	15
# West Englewood	1
# South Deering	1
# South Chicago	6
# West Garfield Park	2
# Belmont Cragin	9
# Lake View	660
# Edgewater	194
# Near West Side	261
# North Park	10
# Beverly	6
# Albany Park	45
# Logan Square	496
# Forest Glen	5
# Bridgeport	65
# Roseland	2
# Oakland	20
# South Lawndale	29
# Irving Park	112
# Near North Side	487
# Archer Heights	2
# New City	6
# Kenwood	52
# Hegewisch	2
# Uptown	260
# Montclare	1
# Calumet Heights	3
# Auburn Gresham	4
# Jefferson Park	16
# Washington Heights	1
# Lincoln Park	345
# Garfield Ridge	3
# West Pullman	1
# Hyde Park	103
# North Lawndale	21
# Gage Park	1
# Englewood	5
#
#  Oakland
# Lincoln Highlands	9
# Hoover-Foster	13
# Shafter	35
# Leona Heights	5
# Upper Rockridge	40
# Frick	5
# Trestle Glen	19
# Lynn-Highland Park	12
# Golf Links	9
# Bella Vista	6
# Clinton	15
# Allendale	3
# Jefferson	7
# Oak Tree	1
# Redwood Heights	13
# Civic Center	9
# Fairview Park	39
# Toler Heights	4
# Glenview	32
# Sequoyah	13
# Upper Peralta Creek-Bartlett	1
# Rancho San Antonio	2
# Cleveland Heights	49
# Forestland	10
# McClymonds	13
# Laurel	4
# Acorn-Acorn Industrial	1
# Montclair	19
# Lakeshore	38
# Upper Laurel	16
# Prescott	44
# Woodland	1
# Woodminster	2
# Melrose	3
# Durant Manor	4
# Hawthorne	1
# Joaquin Miller Park	1
# Dimond	8
# Peralta-Hacienda	2
# Millsmont	14
# Tuxedo	5
# Bancroft Business-Havenscourt	1
# Santa Fe	35
# Waverly	4
# Lakewide	20
# Oakland Ave-Harrison St	34
# Panoramic Hill	4
# Sausal Creek	5
# Upper Dimond	7
# Eastmont	4
# Produce And Waterfront	14
# Hiller Highlands	1
# South Kennedy Tract	4
# Piedmont Avenue	60
# Clawson	24
# Webster	1
# Oak Center	20
# Ivy Hill	12
# South Prescott	5
# Chabot Park	9
# Claremont	8
# School	4
# Maxwell Park	16
# Fremont	5
# Grand Lake	35
# Piedmont	15
# Ralph Bunche	15
# Shepherd Canyon	16
# Harrington	1
# Merritt	14
# Pill Hill	11
# Highland	1
# Merriwood	22
# San Pablo Gateway	18
# Lake Merritt	10
# Crestmont	2
# Paradise Park	19
# Fairfax	4
# Temescal	59
# Eastmont Hills	16
# Sheffield Village	2
# Bushrod	92
# Coliseum	1
# Bartlett	2
# Gaskill	12
# Adams Point	50
# Piedmont Pines	11
# Reservoir Hill-Meadow Brook	10
# Longfellow	54
# Peralta-Laney	1
# Sobrante Park	1
# Crocker Highland	16
# Caballo Hills	10
# Oakmore	28
# Mountain View Cemetery	9
# Golden Gate	20
# Mosswood	23
# Glen Highlands	8
# Skyline-Hillcrest Estates	2
# East Peralta	7
# Old City-Produce And Waterfront	12
# Rockridge	33
# Highland Terrace	6
# Patten	1
#
#  SanDiego
# Memorial	16
# Marina	52
# Mission Bay	448
# West University Heights	88
# Rancho Bernadino	25
# El Cerritos	9
# Gaslamp Quarter	54
# San Ysidro	8
# Talmadge	17
# Cortez Hill	44
# Del Mar Heights	46
# Gateway	9
# City Heights East	13
# La Jolla Village	23
# Old Town	84
# Jomacha-Lomita	1
# Kensington	30
# Ocean Beach	226
# Pacific Beach	465
# Darnall	12
# Palm City	6
# Mountain View	5
# Del Cerro	15
# Carmel Valley	46
# Alta Vista	3
# Midtown District	27
# Columbia	13
# Rolando	12
# Linda Vista	43
# Horton Plaza	1
# Bay Park	72
# San Carlos	17
# Loma Portal	194
# North Clairemont	34
# Grant Hill	51
# Rancho Penasquitos	41
# East Village	175
# Mount Hope	2
# Little Italy	93
# North City	17
# College Area	36
# Scripps Ranch	21
# Bird Land	9
# Mira Mesa	46
# Kearny Mesa	7
# Sabre Springs	2
# Balboa Park	141
# Bay Ho	37
# Sky Line	2
# Moreno Mission	55
# Sorrento Valley	12
# Bay Terrace	2
# Paradise Hills	11
# Oak Park	10
# Grantville	28
# Roseville	51
# Bario Logan	4
# Nestor	3
# Clairemont Mesa	78
# Serra Mesa	41
# Chollas View	3
# Park West	74
# Torrey Pines	12
# Egger Highlands	1
# La Jolla	327
# Allied Gardens	7
# Valencia Park	1
# City Heights West	45
# Wooded Area	23
# Core	47
# Normal Heights	79
# Encanto	11
# Tierrasanta	11
# Lake Murray	9
# University City	108
# Southcrest	9
# Carmel Mountain	3
#
#  Nashville
#
#  SantaCruz
#
#  Denver
# Baker	55
# Five Points	160
# Lincoln Park	34
# Auraria	3
# Highland	97
# City Park	9
# Jefferson Park	39
# Capitol Hill	114
# University	17
# Cherry Creek	10
# Stapleton	22
# Windsor	6
# Washington Park	13
#
#  Seattle
# Alki	34
# South Lake Union	16
# Seward Park	42
# Leschi	47
# Cedar Park	5
# Fremont	152
# Roxhill	2
# Arbor Heights	6
# Interbay	12
# University District	79
# Green Lake	42
# Victory Heights	11
# International District	12
# Whittier Heights	25
# Windermere	8
# Laurelhurst	7
# Brighton	13
# Greenwood	87
# Crown Hill	17
# First Hill	65
# Industrial District	8
# Lower Queen Anne	75
# Wedgwood	14
# Atlantic	39
# Maple Leaf	33
# Westlake	10
# Highland Park	11
# South Delridge	11
# Belltown	155
# Columbia City	62
# View Ridge	6
# Haller Lake	10
# Phinney Ridge	63
# North College Park	16
# Ravenna	65
# Loyal Heights	51
# Sunset Hill	11
# Montlake	18
# Bryant	27
# Riverview	9
# Bitter Lake	11
# Madison Park	17
# Portage Bay	17
# Fauntleroy	11
# Matthews Beach	16
# Olympic Hills	12
# Meadowbrook	8
# South Park	2
# North Delridge	29
# Rainier Beach	13
# Wallingford	145
# Georgetown	8
# High Point	14
# Eastlake	45
# Madrona	40
# Pioneer Square	17
# Broadview	17
#
#  WDC
#
#  Boston
# Mattapan	19
# Roxbury	114
# Jamaica Plain	302
# Roslindale	52
# South Boston	132
# West Roxbury	28
# Hyde Park	22
# South End	226
# East Boston	105
# Charlestown	90
#
#  NewOrleans
# Bywater	302
# Audubon	155
# West End	24
# Fillmore	43
# Pontchartrain Park	4
# Garden District	60
# Fairgrounds	241
# Mid-City	387
# Navarre	22
# Dillard	20
# Black Pearl	43
# Seventh Ward	468
# Gentilly Woods	6
# Touro	83
# Central City	289
# Lake Catherine	5
# French Quarter	421
# Little Woods	24
# Lakeview	47
# West Riverside	133
# Read Blvd East	7
# Old Aurora	17
# Milneburg	40
# East Riverside	110
# Whitney	14
# Central Business District	237
# Leonidas	182
# City Park	97
# Plum Orchard	4
# Lower Garden District	309
# Irish Channel	142
# Lakewood	5
# Gentilly Terrace	90
# Broadmoor	90
# Pines Village	1
# Milan	153
# Freret	47
# Read Blvd West	1
# Uptown	150
# Gert Town	12
# West Lake Forest	2
# Marigny	348
# Holy Cross	58
# Dixon	6
# Mcdonogh	19
# Behrman	2
#
#  LA
# Glassell Park	115
# Calabasas	59
# Echo Park	761
# Valinda	4
# Harbor Gateway	33
# Glendora	17
# Brentwood	259
# Winnetka	38
# Van Nuys	182
# Temple City	54
# West Hills	65
# West Puente Valley	1
# Pico Rivera	20
# Watts	3
# North El Monte	7
# South San Gabriel	6
# Charter Oak	4
# West Adams	71
# Marina del Rey	183
# Hawthorne	86
# Downey	30
# Boyle Heights	61
# Inglewood	164
# Arleta	2
# Hacienda Heights	88
# South El Monte	4
# Avalon	11
# Venice	2489
# Citrus	1
# West Los Angeles	136
# East Pasadena	21
# Lawndale	44
# Diamond Bar	68
# Hollywood Hills	1009
# Granada Hills	39
# Westmont	12
# Palms	403
# Palmdale	19
# Montebello	17
# Palos Verdes Estates	20
# El Sereno	64
# Santa Clarita	71
# Rancho Palos Verdes	76
# East San Gabriel	24
# Gardena	86
# Burbank	290
# La Puente	15
# Industry	28
# Century City	46
# Claremont	32
# Lincoln Heights	70
# Ramona	4
# Panorama City	20
# Hawaiian Gardens	4
# Valley Village	167
# Monterey Park	81
# East Los Angeles	36
# Manhattan Beach	245
# Eagle Rock	189
# La Crescenta-Montrose	14
# Pacoima	11
# Highland Park	316
# Sawtelle	534
# Tarzana	102
# Playa Vista	101
# Atwater Village	154
# Norwalk	8
# Reseda	89
# Malibu	370
# North Hills	16
# Silver Lake	875
# Encino	137
# Northridge	78
# Canoga Park	53
# El Monte	41
# Long Beach	1140
# Baldwin Park	6
# La Mirada	17
# Pasadena	614
# La Verne	19
# West Hollywood	1155
# Alhambra	125
# South Whittier	8
# Agoura Hills	49
# Bellflower	10
# Sunland	11
# Cerritos	25
# Whittier	60
# Alondra Park	9
# Avocado Heights	11
# Acton	2
# Monrovia	51
# Del Aire	24
# Hermosa Beach	290
# North Hollywood	544
# Walnut	57
# Cypress Park	30
# Pomona	59
# San Pasqual	8
# La Habra Heights	32
# Westwood	413
# Signal Hill	19
# Lomita	25
# Agua Dulce	11
# Topanga	272
# Studio City	464
# Irwindale	3
# San Pedro	126
# Santa Fe Springs	4
# Torrance	187
# View Park-Windsor Hills	51
# Chinatown	71
# Willowbrook	5
# Sierra Madre	22
# Carson	48
# Lakewood	39
# Mayflower Village	8
# Pico-Robertson	208
# Mount Washington	165
# Stevenson Ranch	17
# South Park	7
# Rosemead	18
# Huntington Park	6
# South Pasadena	84
# Hasley Canyon	1
# Pacific Palisades	215
# Hyde Park	46
# Duarte	5
# Del Rey	401
# Sun Valley	54
# El Segundo	102
# Rolling Hills Estates	13
# Shadow Hills	19
# Redondo Beach	346
# Bell	6
# Castaic	5
# Compton	7
# Chatsworth	32
# Beverly Hills	500
# Lynwood	1
# Vincent	3
# West Covina	47
# Santa Monica	1510
# Westchester	259
# Harbor City	13
# South Gate	8
# Toluca Lake	100
# Artesia	4
# Woodland Hills	284
# Westlake Village	6
# Altadena	179
# Fairfax	384
# Rowland Heights	261
# Covina	17
# Lake Hughes	1
# Hollywood	2230
# Azusa	29
# Montecito Heights	85
# Tujunga	20
# West Carson	18
# Glendale	313
# Lancaster	21
# San Gabriel	70
# Westlake	506
# Paramount	12
# San Fernando	3
# Val Verde	6
# Culver City	307
# Los Feliz	628
# San Marino	10
# Ladera Heights	33
# Arcadia	137
# La Cañada Flintridge	25
# Sylmar	25
# Jefferson Park	75
# San Dimas	16
# Mar Vista	462
#
#  Austin

# %% [markdown]
# - Check the stored info

# %%
info_pd = pd.DataFrame(pickle.load(open(data_path+'city_hood_byview.pickle','rb')))

# %%
info_pd.head()
# Out:
#   city  city_crime         hood  hood_crime  \
# 0   NY       0.006  Cobble Hill    0.002294
# 1   NY       0.006  Cobble Hill    0.002294
# 2   NY       0.006  Cobble Hill    0.002294
# 3   NY       0.006  Cobble Hill    0.002294
# 4   NY       0.006  Cobble Hill    0.002294
#
#                                       hood_overviews
# 0  Cobble Hill is a wonderful neighborhood with s...
# 1  I love everything about the neighborhood. It i...
# 2  Squeezed between the similarly charming (and h...
# 3  An ideal spot.  One of the best neighborhoods ...
# 4  We are located on Smith Street, and are in wal...

# %%
info_pd[info_pd['hood'] == 'Ocean View'][:10]
# Out:
#                city  city_crime        hood  hood_crime  \
# 49291  SanFrancisco       0.007  Ocean View    0.006098
# 49292  SanFrancisco       0.007  Ocean View    0.006098
# 49293  SanFrancisco       0.007  Ocean View    0.006098
# 49294  SanFrancisco       0.007  Ocean View    0.006098
# 49295  SanFrancisco       0.007  Ocean View    0.006098
# 49296  SanFrancisco       0.007  Ocean View    0.006098
# 49297  SanFrancisco       0.007  Ocean View    0.006098
# 49298  SanFrancisco       0.007  Ocean View    0.006098
# 49299  SanFrancisco       0.007  Ocean View    0.006098
# 49300  SanFrancisco       0.007  Ocean View    0.006098
#
#                                           hood_overviews
# 49291  We are located in Merced Heights which is a 15...
# 49292  Ingleside still retains old-school charm of Sa...
# 49293  We are located in Merced Heights which is a 15...
# 49294  There are tennis, basketball courts and soccer...
# 49295  Cultural diversity of this neighborhood is phe...
# 49296  Daly City is the next city just south of San F...
# 49297  Ingleside is a quite residential area for the ...
# 49298  Our charming cozy house is close to 280 freewa...
# 49299  Ingleside is a lesser know and wonderful neigb...
# 49300  The location in Ingleside is close to City Col...

# %% [markdown]
# <a id='part3'></a>
# ### 3.Generate common words among several cities [Home](#home)<br>
# #### 3.1. Common words, remove city specific words<br>

# %%
def iter_views(data_pd):
    for city in Counter(data_pd.city):
        city_pd = data_pd[data_pd['city'] == city]
        for hood in Counter(city_pd.hood):
            hood_pd = city_pd[city_pd['hood'] == hood]
            yield from hood_pd['hood_overviews'].values

# %%
def select_general_wds(data_file,n_tf,n_city):
    data_pd = pd.DataFrame(pickle.load(open(data_file,'rb')))
    data_vec = CountVectorizer(binary=True, ngram_range=(1,1))
    X_all = data_vec.fit_transform(iter_views(data_pd))
    
    all_vocab = data_vec.get_feature_names()
    print(X_all.shape)
    
    city_vec = CountVectorizer(binary=True, ngram_range=(1,1), vocabulary = all_vocab)
    n_city_feat = np.zeros(X_all.shape[1])
    n_min_tf = np.zeros(X_all.shape[1])
    
    for city in Counter(data_pd.city):
        print(city)
        city_pd = data_pd[data_pd['city'] == city]
        city_views = city_pd['hood_overviews'].values
        
        X_city = city_vec.fit_transform(city_views)
        n_city_feat += [1 if tf>=n_tf else 0 for tf in X_city.sum(axis=0).A1]
        n_tf_feat = [tf if tf>=n_tf else 0 for tf in X_city.sum(axis=0).A1]
        
        # record each existing word's min term frequency in each city
        if(np.all(n_min_tf == 0)):
            n_min_tf = n_tf_feat
        else:
            for tf_i in range(X_city.shape[1]):
                if(n_tf_feat[tf_i]>0 and n_min_tf[tf_i]>0):
                    n_min_tf[tf_i] = min(n_tf_feat[tf_i],n_min_tf[tf_i])
                elif(n_tf_feat[tf_i]==0 or n_min_tf[tf_i]==0):
                    n_min_tf[tf_i] = max(n_tf_feat[tf_i],n_min_tf[tf_i])
                else:
                    print("error")
      
    remain_feat_idx = np.where(n_city_feat>=n_city)[0]
    remain_feats_info = {}
    for idx in remain_feat_idx:
        remain_feats_info[all_vocab[idx]] = [n_min_tf[idx],n_city_feat[idx]]
    
    return all_vocab, remain_feats_info

# %%
all_vocab, remain_feats_info = select_general_wds(data_path+'city_hood_byview.pickle',n_tf=8,n_city=6)
# Out:
# (99620, 45866)
# NY
# Portland
# Denver
# SanFrancisco
# Chicago
# Seattle
# NewOrleans
# Boston
# Oakland
# SanDiego
# LA

# %%
print("%d out of %d words are selected." % (len(remain_feats_info),len(all_vocab)))
# Out:
# 1550 out of 45866 words are selected.

# %%
def write_feat_tofile(wd_log,feats_info):
    with open(wd_log,'w') as fw:
        myfields = ['word','min_tf','n_cities']
        feat_csv = csv.DictWriter(fw,fieldnames = myfields)
        feat_csv.writeheader()
        for wd in feats_info:
            feat_csv.writerow({'word':wd, 'min_tf':feats_info[wd][0], 'n_cities':feats_info[wd][1]})
#write_feat_tofile(data_path+'common_wds.csv',remain_feats_info)

# %% [markdown]
# #### Not remove stop words in CountVectorizer
# - words removed by using stop_words='english'
# - http://ir.dcs.gla.ac.uk/resources/linguistic_utils/stop_words
# - some words in stop word list are meaningful.
