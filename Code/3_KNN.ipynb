# %% [markdown]
# ### Lexical Substitution Effect estimation using KNN
# - K=30

# %%
import requests, time, operator, re, json, csv, pickle, copy, ast
import pandas as pd
import numpy as np
from collections import Counter
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from nltk.corpus import stopwords
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from ast import literal_eval
from scipy.sparse import vstack
from scipy.spatial.distance import cdist
import sklearn.metrics.pairwise
import matplotlib.pyplot as plt
#%matplotlib inline

import warnings
warnings.filterwarnings("ignore")
AMT_path = '/data/2/zwang/2018_S_WordTreatment/V2_AMT/'
airbnb_path = '/data/2/zwang/2018_S_WordTreatment/V2_airbnb/'
tw_path = '/data/2/zwang/2018_S_WordTreatment/V2_twitter/'
yp_path = '/data/2/zwang/2018_S_WordTreatment/V2_yelp/'

# %%
def knn_treatment_for_pair(swd,swdi,twd,twdi,X_sents,source_sents,source_labels,X_source,target_sents,target_labels,X_target,n_neighbors):
    """
    LSE for every sentence of every word pair
    """
    source_pos_treatment = []
    source_neg_treatment = []
    target_pos_treatment = []
    target_neg_treatment = []
    
    if(X_sents.shape[0]*X_sents.shape[1] < 600000000): # control for memory error
        X_src_ = X_source[:]
        X_src_[:,swdi] = 0
        X_tar_ = X_target[:]
        X_tar_[:,twdi] = 0
        
        s_t_sim = cosine_similarity(X_src_,X_target)
        t_s_sim = cosine_similarity(X_tar_,X_source)
        s_s_sim = cosine_similarity(X_src_, X_source)
        t_t_sim = cosine_similarity(X_tar_, X_target)
        
        for i in range(X_src_.shape[0]):
            treat_neighbor_idx = s_t_sim[i].argsort()[::-1][:min(n_neighbors,X_target.shape[0])]
            treat_neighbor_labels = [target_labels[idx] for idx in treat_neighbor_idx]
            
            contrl_neighbor_idx = s_s_sim[i].argsort()[::-1][1:min(n_neighbors+1,X_source.shape[0])]
            contrl_neighbor_labels = [source_labels[idx] for idx in contrl_neighbor_idx]
            
            effect = np.mean(treat_neighbor_labels) - np.mean(contrl_neighbor_labels)
            
            if(source_labels[i]==1):
                source_pos_treatment.append((source_sents[i],round(float(effect),5)))
            elif(source_labels[i]==0):
                source_neg_treatment.append((source_sents[i],round(float(effect),5)))
    
        for j in range(X_tar_.shape[0]):
            treat_neighbor_idx = t_s_sim[j].argsort()[::-1][:min(n_neighbors,X_source.shape[0])]
            treat_neighbor_labels = [source_labels[idx] for idx in treat_neighbor_idx]
        
            contrl_neighbor_idx = t_t_sim[j].argsort()[::-1][1:min(n_neighbors+1,X_target.shape[0])]
            contrl_neighbor_labels = [target_labels[idx] for idx in contrl_neighbor_idx]
        
            effect = np.mean(treat_neighbor_labels) - np.mean(contrl_neighbor_labels)
        
            if(target_labels[j]==1):
                target_pos_treatment.append((target_sents[j],round(float(effect),5)))
            elif(target_labels[j]==0):
                target_neg_treatment.append((target_sents[j],round(float(effect),5)))
        
        return {'source':swd,'target':twd,
            'source_pos_sents_treatment':[source_pos_treatment],'source_neg_sents_treatment':[source_neg_treatment],
            'target_pos_sents_treatment':[target_pos_treatment],'target_neg_sents_treatment':[target_neg_treatment]}
    else:
        print("Large matrix!",swd,twd)
        return None

# %%
def cal_KNN_treatment(pair_file,treat_file,vocab_file,n_neighbors):
    """
    Iteratively calculating LSE for every word pair
    """
    wdpairs_pos_neg_pd = pd.DataFrame(pickle.load(open(pair_file,'rb')))
    if(vocab_file):
        my_vocab = list(set(pd.read_csv(vocab_file).word.values))
        tfidf_vec = TfidfVectorizer(norm='l2',vocabulary=my_vocab)
        print(len(my_vocab))
    else:
        tfidf_vec = TfidfVectorizer(norm='l2')
    
    with open(treat_file,'wt') as fw:
        my_fields = ['source','target','source_pos_sents_treatment','source_neg_sents_treatment','target_pos_sents_treatment','target_neg_sents_treatment']
        csv_f = csv.DictWriter(fw,fieldnames=my_fields)
        csv_f.writeheader()
            
        for idx, row in wdpairs_pos_neg_pd.iterrows():
            if(idx % 100 == 0):
                print("-------------",idx,"-------------")
            swd = row['source']
            twd = row['target']
            swd_pos_sents = row['source_pos_sents']
            swd_neg_sents = row['source_neg_sents']
            twd_pos_sents = row['target_pos_sents']
            twd_neg_sents = row['target_neg_sents']
            
            source_sents = swd_pos_sents + swd_neg_sents
            target_sents = twd_pos_sents + twd_neg_sents
            source_labels = list(np.ones(len(swd_pos_sents)))+list(np.zeros(len(swd_neg_sents)))
            target_labels = list(np.ones(len(twd_pos_sents)))+list(np.zeros(len(twd_neg_sents)))
    
            X_sents = tfidf_vec.fit_transform(source_sents+target_sents)
            vocab = tfidf_vec.vocabulary_
#             return source_sents+target_sents,X_sents,tfidf_vec
            swdi = vocab[swd]
            twdi = vocab[twd]
            
            X_source = X_sents[:len(source_sents)]
            X_target = X_sents[len(source_sents):]
            
            
            #logger.debug("swd: %s, twd: %s, X_sents.shape: %s" % (swd,twd,X_sents.shape))
            #print(swd, twd, X_sents.shape)
            
            treat_info = {}
            treat_info = knn_treatment_for_pair(swd,swdi,twd,twdi, X_sents,
                                                source_sents,source_labels,X_source,
                                                target_sents,target_labels,X_target,n_neighbors)
            
            if(treat_info):
                csv_f.writerow({'source':treat_info['source'],'target':treat_info['target'],
                            'source_pos_sents_treatment':treat_info['source_pos_sents_treatment'],'source_neg_sents_treatment':treat_info['source_neg_sents_treatment'],
                            'target_pos_sents_treatment':treat_info['target_pos_sents_treatment'],'target_neg_sents_treatment':treat_info['target_neg_sents_treatment']})

# %% [markdown]
# - Only using AMT labeled data

# %%
prefix = "yp"
pair_file = AMT_path+'AMT_WdSents/Data/'+prefix+'_AMT_wdsents_markPPN.pickle'
treat_file = AMT_path +"AMT_WdSents/3_KNN/"+prefix+"_knn_30_treatment.csv"
#vocab_file=airbnb_path+'0_Data/common_wds.csv'
start = time.time()
cal_KNN_treatment(pair_file,treat_file,vocab_file='',n_neighbors=30)
end = time.time()
print((end-start)/60)
# Out:
# ------------- 0 -------------
# 2.705143372217814

# %%
res_pd = pd.read_csv(AMT_path +"AMT_WdSents/3_KNN/yp_knn_30_treatment.csv",index_col=False)
res_pd.shape
# Out:
# (18, 6)

# %%
res_pd.tail()
# Out:
#       source       target                         source_pos_sents_treatment  \
# 13  gorgeous     terrific  [[('A previous reviewer mentioned gorgeous sta...
# 14  gorgeous    excellent  [[('A previous reviewer mentioned gorgeous sta...
# 15  fabulous    excellent  [[('_NNP_ atmosphere fabulous pizza amazing co...
# 16  gorgeous  outstanding  [[('A previous reviewer mentioned gorgeous sta...
# 17      cute    excellent  [[("I 've been back _NUMBER_ or _NUMBER_ times...
#
#                            source_neg_sents_treatment  \
# 13  [[('Gorgeous theater lobby almost like a _NNP_...
# 14  [[('Gorgeous theater lobby almost like a _NNP_...
# 15  [[("The chips and salsa are great and it is ea...
# 16  [[('This hotel really is gorgeous and luxuriou...
# 17  [[('What a cute little local coffee shop ! ', ...
#
#                            target_pos_sents_treatment  \
# 13  [[('The blue cheese really popped and gave it ...
# 14  [[('The food was excellent and was visually ap...
# 15  [[('The food was excellent and was visually ap...
# 16  [[('their wine list is decently sized and the ...
# 17  [[('But the food is really excellent . ', -0.5...
#
#                            target_neg_sents_treatment
# 13  [[('Had a terrific time . ', -0.63333), ('We h...
# 14  [[('Very cute little place , great food , exce...
# 15  [[('Very cute little place , great food , exce...
# 16  [[('More positives : The costumer service is g...
# 17  [[('Very cute little place , great food , exce...

# %%
ast.literal_eval(res_pd.iloc[-1]['source_pos_sents_treatment'])
# Out:
# [[("I 've been back _NUMBER_ or _NUMBER_ times since I first dropped by and it 's so damn cute ... _NNP_ , the owner , greets me like a long lost son every time ... and she never remembers that I 've been in before ! ",
#    0.26667),
#   ("The decor here is very cute and goes well in the _NNP_ _NNP_ area ... _NNP_ is prompt and some days get busier than others ... _NNP_ job _NNP_ 's # _NUMBER_ ... ",
#    0.63333),
#   ("If you like to order your drinks by color and suck from a fistful of straws from a fishbowl ... and watch college kids fight and vomit , _NNP_ 's is the place for you ... and it is fun , the boys are cute and unconcious , what more could you ask for ? ",
#    0.4),
#   ('Very cute little place perfect for a warm and cozy coffee break ! ', 0.3),
#   ('The chopsticks , pots , bowls , and even how kimchi is presented is very cute . ',
#    0.4),
#   ('_NNP_ a cute used bike -- a cruiser -- for my wife . ', 0.56667),
#   ('Cute little spot about _NUMBER_ - _NUMBER_ minutes from the strip . ',
#    0.2),
#   ('Stitch is a cute place and the staff is super friendly . ', 0.46667),
#   ('The gift shop on the inside is amazing -- never have we seen a collection of so many cute and unusual things , from standard _NNP_ souveniers to original art pieces , and a wide range of prices too . ',
#    0.4),
#   ('Good Burgers , Good Wings , _NNP_ _NNP_ , Nicely portioned shots , _NUMBER_ outta _NUMBER_ waitresses are cute , all your typical bar fixings done well . ',
#    0.23333),
#   ("It 's a pretty small place and it has a cute little bar . ", 0.46667),
#   ("Still very expensive , but the bartender was very cute and that 's always a good thing . ",
#    0.36667),
#   ('Food is consistent , items in the store are always changing for the seasons and they have really cute things . ',
#    0.5),
#   ('A very cute statue of a very cute dog . ', 0.06667),
#   ('This location is great as far as customer service , food quality , and the set up is super cute . ',
#    0.53333),
#   ("The inside is cute but it has an unusual smell , I think it 's from the bathrooms . ",
#    0.4),
#   ('Cute place tucked away in the strip mall . ', 0.43333),
#   ('My fiends and I usually sit at the tables near the bar but they have cute little couches on the east side . ',
#    0.26667),
#   ('_NNP_ cute inside . ', 0.53333),
#   (':-LRB- the decor is cute and the bathrooms themselves look very nice . ',
#    0.36667),
#   ('Our cute _NNP_ _NNP_ native , _NNP_ suggested the best things on the menu - even telling us what was off and on from the specials board that would work or not . ',
#    0.53333),
#   ('When I pick up my puffs they are so cute and return particularly happy like they came from a dog spa and was pampered for hours . ',
#    0.26667),
#   ('So I came in and was immediately greeted by a cute girl named _NNP_ , and I explained my dilemma and she got me in a chair and fixed my botched hair , within a matter of minutes ! ',
#    0.3),
#   ('While passing through _NNP_ _NNP_ , on our way to _NNP_ , we stopped into this cute juice bar with some really cool bicycles in front . ',
#    0.46667),
#   ('The staff was great - they picked up a plate from me and some sauce spilled on my dress , _NUMBER_ staff members , including the owner came over and scrubbed my dress clean - it was quite cute actually . ',
#    0.4),
#   ("_NNP_ seems like a cute bar scene for those into football games or any type of game as they have huge tv 's and a projector screen . ",
#    0.36667),
#   ('We was received by some very cute girls , and very nice guys , we was served by _NNP_ and _NNP_ . ',
#    0.0),
#   ('Very cute setting lined with table umbrellas . ', 0.3),
#   ("And it 's a cute little french restaurant . ", 0.5),
#   ('Our waitress was cute and friendly and attentive . ', 0.26667),
#   ('Such a cute place . ', 0.53333),
#   ("From the incredibly cute waitresses -LRB- for the most part , but I 'm a gentleman and not perfect myself so no judging -RRB- who serve with a smile . ",
#    0.3),
#   ('We are picky due to our dog being so cute and small , _NUMBER_ yorkie , so we need a full pro on him , not just anyone that cuts dogs hair . ',
#    0.36667),
#   ('Love this cute place ! ', 0.53333),
#   ('_NNP_ ice cream , cute shop , steep prices , limited seating , but well worth the visit ! ',
#    0.56667),
#   ('Some of them are even cute . ', 0.43333),
#   ('Cute place and awesome staff . ', 0.43333),
#   ("Just inside the entrance of _NNP_ _NNP_ _NNP_ which is a great place to hang out - kids or not -RRB- , this cute little hotdog joint delivers unique hotdogs and even allows you to make your own if you 'd like . ",
#    0.4),
#   ('Servers were cute , friendly and polite . ', 0.23333),
#   ('The other patrons were cute and fun . ', 0.36667),
#   ("This is such a cute little place with the best chai latte I 've ever had ! ",
#    0.26667),
#   ('It is such a cute , modern bar with a bikey flair ... ', 0.46667),
#   ('I loved watching the bungee jumping channel very cute . ', 0.13333),
#   ('I got the _NNP_ _NNP_ sammich which was divine I also had a caramel latte and it too was cute What totally made my visit was when the _NNP_ mens rugby team walked in ... ',
#    0.4),
#   ("I saw people of all ages there , including this cute couple in their _NUMBER_ 's hanging out at _NNP_ _NNP_ _NNP_ night watching the _NNP_ game . ",
#    0.53333),
#   ('Oh , and fresh juice in these super cute jars ! ', 0.23333),
#   ('Plus the ladys working are very cute $ _NUMBER_ _NNP_ $ _NUMBER_ _NNP_ $ _NUMBER_ ',
#    0.16667),
#   ('_NUMBER_ _NNP_ of fries was cute and noshy . ', 0.36667),
#   ('I do feel the food quality , atmosphere , and cute waitresses gives value to the menu price . ',
#    0.46667),
#   ('cute little shop near _NNP_ . ', 0.63333),
#   ('When I first saw this place , it looked really cute from far away . ',
#    0.3),
#   ('As for _NNP_ and me , we can not wait to go back to _NNP_ again and pay this cute place another visit ! ',
#    0.23333),
#   ('The minicupcakes are cute and taste sweet but the vanilla has a strange aftertaste from the frosting . ',
#    0.46667),
#   ('_NNP_ ride is cute and realistic . ', 0.66667),
#   ('Definitely recommend , cute atmosphere . ', 0.33333),
#   ("From the looks of it , it has that wilderness look and a set of wooden bears outside , which I thought it was cute , but of course that was n't the only cute thing about it . ",
#    0.33333),
#   ("The guys that work at _NNP_ _NNP_ 's are pretty cute , to boot . ", 0.3),
#   ("_NNP_ 's has a cute theme going on I like the colors The cupcakes are pretty good , very thick in frosting ... ",
#    0.33333),
#   ('Transported to a cute French country farmhouse looking out the doorway and window onto a sea of diners happily eating at a sidewalk caf̩ . ',
#    0.26667),
#   ('It seems to be run by a cute older couple . ', 0.3),
#   ('-LRB- _NNP_ this quality stays consistent looking forward -RRB- We also tried the _NNP_ _NNP_ _NNP_ which was delicious and the presentation was super cute ! ',
#    0.33333),
#   ('The lobby was nice , vast and empty , well except for the cute receptionist at the counter . ',
#    0.4),
#   ('Most dishes were separated into individual portions , such as cute little asian take out boxes for the edamame , and small wire baskets for some of the fried items . ',
#    0.46667),
#   ('Then checked out the tattoo parlor and got a great cup of coffee from a cute little coffee shop in back . ',
#    0.46667),
#   ('This is definitely a cute place to come with your girlfriend or your wife & kids . ',
#    0.36667),
#   ('The really cute part of it , is all these stuff bears all around you . ',
#    0.5),
#   ('The girls were cute and friendly and the beer was reasonably priced . ',
#    0.3),
#   ('It was super cute . ', 0.4),
#   ("It 's got a cute `` vintage/hipster '' look to it . ", 0.33333),
#   ('The girls are cute and perky . ', 0.4),
#   ('_NNP_ , and smartly decorated , with comfortable booths and cute menus . ',
#    0.56667),
#   ('Place is cute but no air conditioning . ', 0.46667),
#   ('Even gave me a cute antenna ball to spread the love . ', 0.13333),
#   ('A cute little place with lovely service . ', 0.33333),
#   ('Food was amazing , prices were very reasonable for the _NNP_ , and I liked the very cute informal atmosphere . ',
#    0.23333),
#   ("She was the one who recommended the _NNP_ _NNP_ and when I ordered the French _NNP_ she was like `` Good choice '' She was cute _NNP_ meal came out and it 's pretty good The French dip is nice and warm and au ` jus is warm as well ... ",
#    0.13333),
#   ("It 's located in a strip mall , and as I write this , _NUMBER_ _NNP_ is torn up , but when we opened the door , we were surprised by the cute , clean , efficient interior . ",
#    0.36667),
#   ('The staff is almost always friendly , the restaurant almost always busy and the store has some really cute stuff . ',
#    0.4),
#   ('She is so cute ! ', 0.16667),
#   ('The little Japanese waitress was so nice and cute , attending to our every needs . ',
#    0.23333),
#   ("I ordered my rolled tacos and salsa and then asked casually `` _NNP_ , have you guys flagged any cute little graphs in a _NNP_ review of _NNP_ _NNP_ , lately ? '' ",
#    0.43333),
#   ('It has a nice quaint feel with checker tablecloths , wooden booths and cute rustic decor . ',
#    0.4),
#   ('The waitresses are young and cute . ', 0.4),
#   ('_NNP_ and get your drink on , they got a cute view thing going on outside , the bar feels small and quaint although it is in the nexus of several of the top restaurants at the _NNP_ . ',
#    0.33333),
#   ("_NNP_ has a really cute layout and color scheme like all the other breakfast joints : Very clean and hip I had the impression that it was a sit down restaurant but it 's an order and seat yourself sort of deal ... ",
#    0.4),
#   ('_NNP_ cute and freaking talented kids ! ', 0.33333),
#   ('_NNP_ a really sweet and cute waitress who made me feel welcome . ',
#    0.36667),
#   ('Food was good , and the bartender was cute . ', 0.3),
#   ('The stuff they have is very cute and very reasonably priced . ', 0.23333),
#   ('-LRB- The wait staff are actually pretty cute , as are the women at the bar ! ',
#    0.16667),
#   ('It was exactly what it claimed to be : a cute boutique hotel with great restaurants , bars , and clubs . ',
#    0.4),
#   ('Cute place , very laid back experience , friendly people ! ', 0.46667),
#   ('The place is small , cozy , and very cute . ', 0.5),
#   ('This is a cute little place , but nothing to rave about . ', 0.4),
#   ('Our waitress was cute as a button and very helpful about the menu . ',
#    0.23333),
#   ("I read great reviews about this place and all the cute pictures of everyone else 's fur baby sealed the deal . ",
#    0.3),
#   ('The wait staff are friendly and cute , our favorite server at this _NNP_ store is _NNP_ , she is friendly , fast , and remembered my drink of choice after only my first week there . ',
#    0.4),
#   ('It Is cute clean and not weird or have any pretentious brunch-slinging waiters with arm sleeve tattoos . ',
#    0.5),
#   ('The color scheme is really cute and the tables and chairs coordinate well ... ',
#    0.43333),
#   ('This is a cute restaurant with seating in back on deck or some inside . ',
#    0.4),
#   ('My son got his snake here a few years ago and a cute new puppy this year . ',
#    0.36667),
#   ('There was even a cute little poodle running around that was super friendly . ',
#    0.46667),
#   ("Came in for breakfast/lunch and ended up getting a mimosa and chicken tenders which is an odd combo but both were equally good _NUMBER_ The chicken tenders were n't greasy Our servers were very helpful and super nice The decor is cute , very earthy ",
#    0.33333),
#   ('I ordered the cherry tea which came in the most perfect tea cup with cute tea pot . ',
#    0.36667),
#   ('This is a very cute , very homely restaurant . ', 0.33333),
#   ('Having a cute cafe in the foot hills makes no sense if the food is no better than the worst cafe in any big city . ',
#    0.46667),
#   ('Ambiance is cute , mildly hipster , but nothing over the top . ', 0.26667),
#   ('We were greated by _NNP_ who was cute , perky , bubbly and friendly and welcomed us warmly . ',
#    0.16667),
#   ("Very very very cute Japanese waitress that I could n't stop drooling over . ",
#    0.1),
#   ('The staff was not only cute but extremely entertaining and best of all they have slab bacon . ',
#    0.36667),
#   ('This place is cute , very comfortable inside and the staff is really nice :-RRB- I got a breakfast sandwich and a white chocolate mocha both were so delicious !! ',
#    0.3),
#   ('I love the design and style , the patio is cute and cozy , and _NNP_ , _NNP_ _NNP_ _NNP_ _NNP_ _NNP_ . ',
#    0.53333),
#   ('Came for _NNP_ shirts and the staff at the shop were super nice and helpful :-RRB- the inside of the hotel/bar is actually really cute . ',
#    0.33333),
#   ("It 's really cute because when you leave you hear them all say thank you , first the waitress , than the woman at the register , and some other tiny voice way in back from a girl I did n't see . ",
#    0.4),
#   ('That also have a cute little bar and some good relaxing music . ', 0.5),
#   ("The lady at the register _NNP_ _NNP_ cute , and I kinda like the `` stab joint '' classic chinese restaurant looks of this place . ",
#    0.46667),
#   ('Such a cute place for a bar street :-RRB- _NNP_ is great and has a good variety of flavors . ',
#    0.43333),
#   ('The presentation was cute . ', 0.5),
#   ('They have some very cute , thoughtful , and inexpensive gifts . ',
#    0.23333),
#   ('The restaurant itself was really cute and mod . ', 0.46667),
#   ('I had only been living in _NNP_ for a week or so and I wanted to find a decent _NNP_ restaurant and _NNP_ _NNP_ looked like a cute little restaurant , and I decided to give it a try . ',
#    0.5),
#   ("_NNP_ egg is cute , it reminds me of the smaller breakfast diners but it 's so big Today , _NNP_ , it is very busy but there was a _NUMBER_ min wait ... Not long ... ",
#    0.5),
#   ('Excellent service and a cute little place in historic _NNP_ . ', 0.56667),
#   ('Found a really cute blazer there . ', 0.53333),
#   ("it 's a cute place , but if you do n't want cute , do n't want to wait , and do n't appreciate the kind of place that matt 's it -- go somewhere else . ",
#    0.36667),
#   ("Today I stopped in for breakfast It 's such a cute little place I got the cheat day wrap and some orange juice The wrap was really good ! ",
#    0.4),
#   ('Not to mention , the girls who work there are cute . ', 0.16667),
#   ('I have taken my Scotty-poo here for several years , and _NNP_ does an amazing job turning her from a scalawag back to a cute little girl again . ',
#    0.2),
#   ("_NNP_ is top notch , chef/owner could be a bit friendlier but that 's okay , and cute little indoor ambiance . ",
#    0.36667),
#   ('She was very polite and cute ;--RRB- I wanted and combo that consisted of half beef and chicken with all rice . ',
#    0.13333),
#   ('The _NNP_ dressing rooms are so cute ', 0.5),
#   ('The menu is a newspaper which is cute . ', 0.73333),
#   ('The place is cute , and has an open kitchen so you can tell the food is made fresh to order . ',
#    0.46667),
#   ('_NNP_ was very cute . ', 0.16667),
#   ('It is a very cute and intimate atmosphere , and I definitely loved that they had extra seating on their second floor . ',
#    0.46667),
#   ('The server , _NNP_ , was as cute as a button and very attentative . ',
#    0.26667),
#   ('A really cute place , service was great , and next time I want to try _NUMBER_ of their renowned milk shakes -LRB- like raspeberry white chocolate cheesecake or Nutella ! ',
#    0.33333),
#   ("I was n't expecting it to be cute ", 0.36667),
#   ('The girls that work at this location are all so very nice and helpful The decor is cute and very historical , a ton of it consists of _NNP_ information and landmarks ... _NNP_ to read or look and eat ... ',
#    0.2),
#   ('Nothing too cute or faux shabby chic about this place , just perfect baked goods and coffee . ',
#    0.2),
#   ('Also picked up a cute basket . ', 0.4),
#   ("I do n't know where to start because everything about this cute little bakery is sooooo freakin ' GOOD ! ",
#    0.4),
#   ('The bakery is this quaint little place that is really cute with nice baking decorations and everything . ',
#    0.63333),
#   ('She is young and cute and very courteous to her customers . ', 0.16667),
#   ('He also has a cute little cafe set up next to his store front . ',
#    0.36667),
#   ('The waitresses are cute and half ... er ... two-thirds naked and they look good this way . ',
#    0.26667),
#   ('It has a great ambience , with cute indie and indie related music . ',
#    0.26667),
#   ('The server , who was very cute and attractive served complementary cured olives and spiced cashews which were nice -- she even gave us a new plate of these when we barely finished the first one . ',
#    0.4),
#   ('It opened up a very cute little box which contained a pastry for us to take home . ',
#    0.23333),
#   ("It 's a cute place to be all drunk , but there are better clubs on the strip . ",
#    0.53333),
#   ('Very friendly and cute little restaurant and the menu looked pretty good from what I saw online , but we only wanted a pie to go . ',
#    0.6)]]

# %%
this_path = airbnb_path
prefix = "airbnb"
pair_file = this_path+"1_Process/"+prefix+"_wdpair_sents_limit5000.pickle"
treat_file = this_path +"3_KNN/"+prefix+"_knn_30_treatment_limitvocab_test.csv"
vocab_file=airbnb_path+'0_Data/common_wds.csv'
sents,X_sents,tfidf_vec = cal_KNN_treatment(pair_file,treat_file,vocab_file,n_neighbors=30)
# Out:
# 1550
# ------------- 0 -------------

# %%
this_path = airbnb_path
prefix = "airbnb"
pair_file = this_path+"1_Process/"+prefix+"_wdpair_sents_limit5000.pickle"
treat_file = this_path +"3_KNN/"+prefix+"_knn_30_treatment.csv"
start = time.time()
cal_KNN_treatment(pair_file,treat_file,n_neighbors=30)
end = time.time()
print((end-start)/60)
# Out:
# ------------- 0 -------------
# ------------- 100 -------------
# ------------- 200 -------------
# ------------- 300 -------------
# ------------- 400 -------------
# ------------- 500 -------------
# ------------- 600 -------------
# ------------- 700 -------------
# ------------- 800 -------------
# 8.920055758953094

# %%
this_path = yp_path
prefix = "yp"
pair_file = this_path+"1_Process/"+prefix+"_wdpair_sents_limit5000.pickle"
treat_file = this_path +"3_KNN/"+prefix+"_knn_30_treatment.csv"
start = time.time()
cal_KNN_treatment(pair_file,treat_file,n_neighbors=30)
end = time.time()
print((end-start)/60)
# Out:
# ------------- 0 -------------
# ------------- 100 -------------
# ------------- 200 -------------
# ------------- 300 -------------
# ------------- 400 -------------
# ------------- 500 -------------
# ------------- 600 -------------
# ------------- 700 -------------
# ------------- 800 -------------
# 23.310502588748932

# %%
this_path = tw_path
prefix = "tw"
pair_file = this_path+"1_Process/"+prefix+"_wdpair_sents_limit5000.pickle"
treat_file = this_path +"3_KNN/"+prefix+"_knn_30_treatment.csv"
start = time.time()
cal_KNN_treatment(pair_file,treat_file,n_neighbors=30)
end = time.time()
print((end-start)/60)
# Out:
# ------------- 0 -------------
# ------------- 100 -------------
# ------------- 200 -------------
# ------------- 300 -------------
# ------------- 400 -------------
# ------------- 500 -------------
# ------------- 600 -------------
# ------------- 700 -------------
# ------------- 800 -------------
# ------------- 900 -------------
# 13.739893937110901

# %% [markdown]
# ### Check neighbors for each individual sentence
